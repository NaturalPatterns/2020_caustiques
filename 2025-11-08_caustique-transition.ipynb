# %% [markdown]
# # Caustiques

# %%
# %pip install -U -r requirements.txt

# %%
import numpy as np
# import cv2
from tqdm.auto import trange, tqdm
import matplotlib
# import matplotlib.gridspec as gs
from matplotlib.gridspec import SubplotParams
import numpy as np
from scipy import ndimage
# from scipy.ndimage import zoom
matplotlib.__version__
# Out:
# '3.10.7'

# %%
# %matplotlib inline

# %%
import os 
from IPython import get_ipython
ip = get_ipython()
# print(ip.user_ns)
study_name = None
if '__vsc_ipynb_file__' in ip.user_ns:
    # https://github.com/msm1089/ipynbname/issues/17
    study_name = os.path.split(os.path.basename(ip.user_ns['__vsc_ipynb_file__']))[1]
elif '__file__' in ip.user_ns:
    study_name = ip.user_ns['__file__']
else:
    import ipynbname
    study_name = ipynbname.name()
study_name = study_name.replace('.ipynb', '')
study_name
# Out:
# '2025-11-08_caustique-transition'

# %%
# %ls -lh {study_name}
# %ls -lh ~/tmp/{study_name}
# Out:
# total 2503680
# -rw-r--r--@ 1 laurent  staff   791M Nov  9 19:39 longue_vague_e66eb70e.mkv
# -rw-r--r--@ 1 laurent  staff   385M Nov  8 22:41 trier_5ab3387c.mkv
# -rw-r--r--@ 1 laurent  staff    21M Nov  8 21:04 trier_vague_2a0be498.mkv
# total 1169686992
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 02:00 longue_caustique_0.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 05:01 longue_caustique_1.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 12:23 longue_caustique_10.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 12:45 longue_caustique_11.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 13:08 longue_caustique_12.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 13:31 longue_caustique_13.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 13:53 longue_caustique_14.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 14:16 longue_caustique_15.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 14:39 longue_caustique_16.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 15:02 longue_caustique_17.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 15:25 longue_caustique_18.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 15:47 longue_caustique_19.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 07:00 longue_caustique_2.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 16:11 longue_caustique_20.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 16:33 longue_caustique_21.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 16:57 longue_caustique_22.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 17:20 longue_caustique_23.npy
# -rw-r--r--@ 1 laurent  staff   4.0G Nov  9 17:49 longue_caustique_24.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 07:44 longue_caustique_3.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 09:19 longue_caustique_4.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 10:12 longue_caustique_5.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 10:40 longue_caustique_6.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 11:13 longue_caustique_7.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 11:36 longue_caustique_8.npy
# -rw-r--r--@ 1 laurent  staff    18G Nov  9 12:00 longue_caustique_9.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_0.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_1.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_10.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_11.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_12.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_13.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_14.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_15.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_16.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_17.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_18.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_19.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_2.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_20.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_21.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_22.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_23.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_24.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_25.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_26.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_27.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_28.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_29.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_3.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_30.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_31.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_32.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_33.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_34.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_35.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_36.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_37.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_38.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_39.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_4.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_5.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_6.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_7.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_8.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague-smooth_9.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:57 longue_vague_0.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:58 longue_vague_1.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:00 longue_vague_10.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:00 longue_vague_11.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:00 longue_vague_12.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:00 longue_vague_13.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:01 longue_vague_14.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:01 longue_vague_15.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:01 longue_vague_16.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:01 longue_vague_17.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:02 longue_vague_18.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:02 longue_vague_19.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:58 longue_vague_2.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:02 longue_vague_20.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:02 longue_vague_21.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:03 longue_vague_22.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:03 longue_vague_23.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:03 longue_vague_24.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:03 longue_vague_25.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:04 longue_vague_26.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:04 longue_vague_27.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:04 longue_vague_28.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:04 longue_vague_29.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:58 longue_vague_3.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:05 longue_vague_30.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:05 longue_vague_31.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:05 longue_vague_32.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:05 longue_vague_33.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:06 longue_vague_34.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:06 longue_vague_35.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:06 longue_vague_36.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:06 longue_vague_37.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague_38.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 16:07 longue_vague_39.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:58 longue_vague_4.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:59 longue_vague_5.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:59 longue_vague_6.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:59 longue_vague_7.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:59 longue_vague_8.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:59 longue_vague_9.npy
# -rw-r--r--@ 1 laurent  staff   1.5G Nov  8 15:33 trier_wave.npy

# %%
# %rm -fr {study_name}
# %rm -fr ~/tmp/{study_name}

# %%
# the higher PRECISION, the bigger the file
PRECISION = 4  # debugging
PRECISION = 8 # low quality
PRECISION = 10 # medium quality
PRECISION = 11 # medium+ quality
PRECISION = 12 # good quality
# PRECISION = 14 # very good quality
# PRECISION = 15 # for production

# https://docs.python.org/3/library/dataclasses.html?highlight=dataclass#module-dataclasses
from dataclasses import dataclass

@dataclass
class init:
    figpath: str = study_name # Folder to store images
    phi: float = 1.61803 # beauty is gold
    tag: str = 'trier' # Tag
    ext: str = 'mkv' # Extension for output
    nx: int = 1*2**PRECISION # number of pixels (vertical)
    ny: int = 1*2**PRECISION # number of pixels (horizontal)
    nframe: int = 24*8 # number of frames for each chunk
    bin_dens: int = 2 # relative bin density
    bin_wave: int = 4 # downsamplig of the wave
    bin_wave_order: int = 2 # order of upsamplig of the wave
    bin_spectrum: int = 2 # bin spacing in spectrum (lower is more CPU)
    seed: int = 2025 # seed for RNG
    H: float = 30.0 # depth of the pool
    variation: float = .20 # variation of diffraction index: http://www.philiplaven.com/p20.html 1.40 at 400 nm and 1.37 at 700nm makes a 2% variation
    sigma: float = 1.0 # smoothing for the gradient
    sf_0: float = 9/nx # frequency in cycles per pixels
    B_sf: float = 1.2 # bandwidth in sf
    V_Y: float = 0.1 # horizontal speed
    V_X: float = 0.382 # vertical speed
    B_V: float = 1. # bandwidth in speed
    # zmin: float = 1.0 # relative minimal value of wave height at the top to generate a gradient (set to 1. to have no gradient)
    # theta: float = 2*np.pi*(2-1.61803) # angle with the horizontal
    theta: float = np.pi/2 # angle with the horizontal
    B_theta: float = 61*np.pi/180 # bandwidth in theta
    # min_lum: float = .01 # global diffusion level for the rendering giving the pedestal value
    radius_in: float = .00
    radius_out: float = .80 #
    do_wrap: bool = True # Cache intermediate output.
    n_bits: int = 16 # bits to save images
    n_jobs: int = -1 # number of jobs to run in parallel
    gamma: float = 2.4 # Gamma exponant to convert luminosity to luminance
    fps: float = 24 # frames per second
    do_cache: bool = True # Cache intermediate output.
    verbose: bool = False # Displays more verbose output.
    do_display: bool = False # Displays images and videos in notebook.

# %%
opt = init()
print(f'Saving our simulations in={opt.figpath}')
# Out:
# Saving our simulations in=2025-11-08_caustique-transition

# %%
# if opt.nframe==1: opt.ext = 'png'

# %%
if opt.n_jobs>1 or opt.n_jobs==-1:
    from joblib import Parallel, delayed
    # from tqdm_joblib import tqdm_joblib   #  pip install tqdm-joblib

# %%
from pprint import pprint
pprint(opt)
# Out:
# init(figpath='2025-11-08_caustique-transition',
#      phi=1.61803,
#      tag='trier',
#      ext='mkv',
#      nx=4096,
#      ny=4096,
#      nframe=192,
#      bin_dens=2,
#      bin_wave=4,
#      bin_wave_order=2,
#      bin_spectrum=2,
#      seed=2025,
#      H=30.0,
#      variation=0.2,
#      sigma=1.0,
#      sf_0=0.002197265625,
#      B_sf=1.2,
#      V_Y=0.1,
#      V_X=0.382,
#      B_V=1.0,
#      theta=1.5707963267948966,
#      B_theta=1.064650843716541,
#      radius_in=0.0,
#      radius_out=0.8,
#      do_wrap=True,
#      n_bits=16,
#      n_jobs=-1,
#      gamma=2.4,
#      fps=24,
#      do_cache=True,
#      verbose=False,
#      do_display=False)

# %%
screen_size_cm = 100 # cm
CM_BY_INCH = 2.54 # this is a constant
screen_size_in = screen_size_cm/CM_BY_INCH
dpi = (opt.nx // opt.bin_dens) / screen_size_in
print(f'Screen size={screen_size_cm}cm={screen_size_in:.3f}in, dpi={dpi:.0f}dpi')
# Out:
# Screen size=100cm=39.370in, dpi=52dpi

# %% [markdown]
# ## utilitaires
#
# Transformation d'une matrice numpy en une animation:

# %%
import imageio

# def make_movie(moviename, frames, fps):
#     with imageio.v2.get_writer(
#         moviename,
#         format='FFmpeg', 
#         mode='I',
#         fps=fps,
#         ) as writer:
#         for i_frame in trange(frames.shape[-1], desc='Generating movie'):
#             # Append the frame to the video writer
#             writer.append_data(frames[..., i_frame])
#     return moviename

# def make_gif(gifname, fnames, fps, do_delete=True):
#     with imageio.get_writer(gifname, mode='I', fps=fps) as writer:
#         for fname in fnames:
#             writer.append_data(imageio.imread(fname))

#     from pygifsicle import optimize
#     optimize(str(gifname))
#     if do_delete: 
#         for fname in fnames: os.remove(fname)
#     return gifname

# https://moviepy.readthedocs.io/en/latest/getting_started/videoclips.html#imagesequenceclip
# def make_movie(mkvname, fnames, fps, do_delete=True):
#     import moviepy.editor as mpy
#     clip = mpy.ImageSequenceClip(fnames, fps=fps)
#     clip.write_videofile(mkvname, fps=fps, codec='libx264', verbose=False, logger=None)
#     if do_delete: 
#         for fname in fnames: os.remove(fname)
#     return mkvname 

# from tqdm import tqdm
# from tqdm.notebook import tqdm
# def make_movie(moviename, fnames, fps):
#     """Create an mkv video from a sequence of image files.

#     Args:
#         moviename (str): Path to the output video file.
#         fnames (list): List of paths to input image files.
#         fps (int): Frames per second for the output video.

#     Returns:
#         str: Path to the created video file.
#     """
#     ffmpeg_params = [
#         "-c:v", "ffv1",                # codec (ffv1 = lossless intra‑frame)
#         "-level", "3",                # highest ffv1 quality level
#         "-pix_fmt", "rgb48le",          # 16‑bit pixel format     pix_fmt: str = "gray16le",   # 16‑bit grayscale, change to "rgb48le" for color
#         "-preset", "veryslow",        # optional – best compression, slower
#     ]
#     with imageio.v2.get_writer(
#         moviename,
#         fps=fps,
#         macro_block_size=1,
#         ffmpeg_log_level="error",   # keep the console tidy
#         # ffmpeg_params=ffmpeg_params,
#     ) as writer:    
#         for fname in tqdm(fnames, desc="Creating video"):
#             print('>>>', fname)
#             frame = imageio.v2.imread(fname, pilmode='I;16')
#             print('bip')
#             frame = frame.astype(np.uint16)
#             writer.append_data(frame)
# #     return moviename

# def make_movie(moviename, frames, fps):
#     with imageio.v2.get_writer(
#         moviename,
#         format='FFmpeg', 
#         codec="libx264rgb",               # 10‑bit H.264 (RGB)
#         ffmpeg_params=[
#             "-pix_fmt", "rgb48le",        # entrée 16‑bit RGB
#             "-vf", "format=yuv420p10le"   # conversion interne 10‑bit YUV
#         ],
#         fps=fps,
#         ) as writer:
#         for i_frame in trange(frames.shape[-1], desc='Generating movie'):
#             # Append the frame to the video writer
#             writer.append_data(frames[..., i_frame])
#     return moviename

# def make_movie_fromlist(moviename, list_of_frames, fps):
#     with imageio.v2.get_writer(
#         moviename,
#         format='FFmpeg', 
#         mode='I',
#         # format='av', 
#         fps=fps,
#         # pixelformat=pix_fmt
#         # codec='ffv1',  # Use FFV1 for lossless compression
#         ) as writer:
#         for frames in list_of_frames:
#             for i_frame in range(frames.shape[-1]):
#                 # Append the frame to the video writer
#                 writer.append_data(frames[..., i_frame])
#     return moviename

# import imageio.v3 as iio
# def make_movie(mkvname, frames, fps):
#     pix_fmt = 'rgb48le' if frames.ndim==3 else 'gray16le'
#     iio.imwrite(
#         mkvname,
#         np.moveaxis(frames, -1, 0),
#         plugin='pyav',
#         codec='ffv1',
#         fps=fps,
#         in_pixel_format=pix_fmt,
#         out_pixel_format=pix_fmt
#     )
#     return mkvname

# import cv2, numpy as np

# def make_movie(fname, frames, fps=24):
#     h, w, c, n = frames.shape
#     fourcc = cv2.VideoWriter_fourcc(*'avc1')   # codec H.264
#     out = cv2.VideoWriter(fname, fourcc, fps, (w, h))
#     for i in range(n):
#         # OpenCV attend BGR → on inverse les canaux
#         bgr = frames[..., i][..., ::-1]
#         out.write(bgr)
#     out.release()
#     return fname

#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import numpy as np
import subprocess as sp
from tqdm import trange
# import shlex               # pour construire la ligne de commande en toute sécurité
import os

def make_movie(
    out_path: str,
    frames: np.ndarray,
    fps: int = 24,
    codec: str = "prores_ks", # "ffv1", #
    pix_fmt: str = "yuv444p16le", # "rgb48le", #
    ffmpeg_path: str = "ffmpeg",
) -> str:
    """
    Encode une séquence d'images 16‑bits (uint16) en vidéo via ffmpeg.
    Le résultat est un fichier .mkv (ou .avi/.mov selon le codec choisi)
    contenant les 16 bits d'information.

    Parameters
    ----------
    out_path : str
        Chemin du fichier de sortie (ex. "movie.mkv").
    frames : np.ndarray
        Tableau 4‑D (N, H, W, C) en uint16. C doit valoir 1 (gris) ou 3 (RGB).
    fps : int
        Cadence d'image.
    codec : str
        Codec ffmpeg (par défaut "ffv1" lossless). Autres possibles : "prores_ks",
        "libx264rgb", "libx265", "libaom-av1", …
    pix_fmt : str
        Pixel‑format ffmpeg compatible avec le codec.
        - "rgb48le"   → 16‑bit RGB (3 × 16)
        - "yuv444p16le" → YUV 4:4:4 16‑bit (pour ProRes, libx264‑10, etc.)
    ffmpeg_path : str
        Chemin vers l'exécutable ffmpeg (ou le nom s'il est dans $PATH).

    Returns
    -------
    str
        Le même chemin que `out_path` (pour chaîner les appels).
    """
    # ---------------------------------------------------------
    # 1️⃣ Vérifications de forme et type
    # ---------------------------------------------------------
    if frames.ndim != 4:
        raise ValueError(f"`frames` doit être 4‑D, shape={frames.shape}")

    h, w, c, n = frames.shape
    print(h, w, c, n)
    if c not in (1, 3):
        raise ValueError(f"Le nombre de canaux doit être 1 ou 3, vous avez {c}")

    if frames.dtype != np.uint16:
        raise TypeError(f"`frames` doit être dtype=uint16, vous avez {frames.dtype}")

    # ---------------------------------------------------------
    # 2️⃣ Construction de la ligne de commande ffmpeg
    # ---------------------------------------------------------
    # Nous utilisons l'option -f rawvideo pour indiquer que les
    # images arrivent en flux binaire sur stdin.
    # -pix_fmt rgb48le indique que chaque pixel est 48 bits (16 bits × 3).
    # -c:v {codec} définit le codec de sortie.
    # -r {fps} fixe la cadence.
    # -vf "format={pix_fmt}" (facultatif) force le format de pixel interne.
    cmd = [
        ffmpeg_path,
        "-y",                         # écraser le fichier de sortie s'il existe
        "-f", "rawvideo",             # le format d'entrée est rawvideo
        "-vcodec", "rawvideo",
        # "-preset", "veryslow",         # compression maximale (plus lent)
        # "-level", "3",                 # qualité maximale du codec ffv1
        "-pix_fmt", pix_fmt,          # pixel‑format d'entrée 
            #    -pixel_format rgb48le \   # 16‑bit per channel, little‑endian
        "-pixel_format", "rgb48le",   # 16‑bit, little‑endian, 3 canaux
        "-s", f"{w}x{h}",             # résolution
        "-r", str(fps),               # fps d'entrée
        "-i", "-",                    # lecture depuis stdin
        "-c:v", codec,                # codec de sortie
        "-pix_fmt", pix_fmt,          # pixel‑format de sortie (doit être compatible)
        "-r", str(fps),               # fps de sortie (on le répète pour être sûr)
        out_path,
    ]

    # ---------------------------------------------------------
    # 3️⃣ Lancement du processus ffmpeg
    # ---------------------------------------------------------
    proc = sp.Popen(
        cmd,
        stdin=sp.PIPE,
        stdout=sp.PIPE,
        stderr=sp.PIPE,
        bufsize=10**8,                # buffer large pour éviter les blocages
    )

    # ---------------------------------------------------------
    # 4️⃣ Envoi des frames une par une (ou en bloc)
    # ---------------------------------------------------------
    # On écrit les données brutes en row‑major order (C‑order) = ce que numpy utilise.
    # Chaque frame est un tableau (H, W, C) en uint16 → on le convertit en bytes.
    try:
        for i in trange(n, desc="Encoding frames"):
            # Convertir le slice en bytes (little‑endian, natif numpy)
            frame_bytes = frames[..., i].tobytes()
            proc.stdin.write(frame_bytes)
        # Signaler à ffmpeg que les données sont terminées
        proc.stdin.close()
    except Exception as e:
        proc.kill()
        raise RuntimeError(f"Erreur pendant le pipe vers ffmpeg : {e}")

    # ---------------------------------------------------------
    # 5️⃣ Récupérer les logs (facultatif)
    # ---------------------------------------------------------
    # out, err = proc.communicate()
    # if proc.returncode != 0:
    #     raise RuntimeError(
    #         f"ffmpeg a renvoyé le code {proc.returncode}\nSTDERR:\n{err.decode()}"
    #     )
    # Sinon tout s’est bien passé
    return out_path




# make_movie("test_video_08.mp4", np.random.randint(0, 2**8-1, (480, 640, 3, 30), dtype=np.uint8), fps=24)
make_movie("test_video_16.mkv", np.random.randint(0, 2**16-1, (480, 640, 3, 300), dtype=np.uint16), fps=24)
# Out:
# 480 640 3 300
# Encoding frames: 100%|██████████| 300/300 [00:05<00:00, 53.30it/s]
# 'test_video_16.mkv'

# %% [markdown]
# Utilities to compute the spectrum of the blue sky and convert them later to RGB values (check out https://laurentperrinet.github.io/sciblog/posts/2020-07-04-colors-of-the-sky.html for details)

# %%
from lambda2color import Lambda2color, xyz_from_xy

# borrowed from https://github.com/gummiks/gummiks.github.io/blob/master/scripts/astro/planck.py
def planck(wav, T):
    import scipy.constants as const
    c = const.c # c = 3.0e+8
    h = const.h # h = 6.626e-34
    k = const.k # k = 1.38e-23
    a = 2.0*h*c**2
    b = h*c/(wav*k*T)
    intensity = a / ( (wav**5) * (np.exp(b) - 1.0) )
    return intensity

def scattering(wav, a=0.005, p=1.3, b=0.45):
    """
    b is  proportionate  to  the  column  density  of  aerosols
    along  the  path  of  sunlight,  from  outside  the  atmosphere
    to  the  point  of  observation
    
    see https://laurentperrinet.github.io/sciblog/posts/2020-07-04-colors-of-the-sky.html for more details

    """
    # converting wav in µm:
    intensity = np.exp(-a/((wav/1e-6)**4)) # Rayleigh extinction by nitrogen
    intensity *= (wav/1e-6)**-4
    intensity *= np.exp(-b/((wav/1e-6)**p)) # Aerosols
    return intensity

# %% [markdown]
# ## calcul des caustiques

# %%
subplotpars = SubplotParams(left=0., right=1., bottom=0., top=1., wspace=0., hspace=0.)
import matplotlib.pyplot as plt
import hashlib
import MotionClouds as mc

class Caustique:
    def __init__(self, opt):
        """
        Image coordinates follow 'ij' indexing, that is,
        * their origin at the top left,
        * the X axis is vertical and goes "down",
        * the Y axis is horizontal and goes "right".

        """
        self.mc = mc
        self.ratio = opt.ny/opt.nx # ratio between height and width (>1 for portrait, <1 for landscape)
        X = np.linspace(0, 1, opt.nx, endpoint=False) # vertical
        Y = np.linspace(0, self.ratio, opt.ny, endpoint=False) # horizontal
        self.xv, self.yv = np.meshgrid(X, Y, indexing='ij')
        self.opt = opt
        # https://stackoverflow.com/questions/16878315/what-is-the-right-way-to-treat-python-argparse-namespace-as-a-dictionary
        self.d = vars(opt)
        os.makedirs(self.opt.figpath, exist_ok=True)
        self.cachepath = os.path.join(os.path.expanduser('~'), 'tmp', self.opt.figpath)
        if opt.verbose: print(f'{self.cachepath=}')
        os.makedirs(self.cachepath, exist_ok=True)
        self.np_dtype = np.uint8 if opt.n_bits==8 else np.uint16
        
        illuminant = xyz_from_xy(0.3127, 0.3291) # a standard white
        # illuminant = xyz_from_xy(0.268375 0.283377) # sky
        # illuminant = xyz_from_xy(0.325998, 0.335354) # sun

        # color conversion class
        self.cs_srgb = Lambda2color(red=xyz_from_xy(0.64, 0.33),
                                    green=xyz_from_xy(0.30, 0.60),
                                    blue=xyz_from_xy(0.15, 0.06),
                                    white=illuminant)
        
        self.wavelengths = self.cs_srgb.cmf[:, 0]*1e-9
        self.N_wavelengths = len(self.wavelengths)
        # multiply by the spectrum of the sky
        intensity5800 = planck(self.wavelengths, 5800.)
        scatter = scattering(self.wavelengths)
        self.spectrum_sky = intensity5800 * scatter
        self.spectrum_sky /= self.spectrum_sky.max()

        self.rgbs = {}
        for i_wavelength in range(self.opt.bin_spectrum//2, self.N_wavelengths, self.opt.bin_spectrum):
            # we convert the spectrum into a color
            spec = np.zeros((self.N_wavelengths))
            spec[i_wavelength] = 1
            rgb = self.cs_srgb.spec_to_rgb(spec)
            rgb *= self.spectrum_sky[i_wavelength]
            self.rgbs[i_wavelength] = rgb

        self.fx, self.fy, self.ft = mc.get_grids(self.opt.nx//self.opt.bin_wave, self.opt.ny//self.opt.bin_wave, self.opt.nframe)

    def wave(self, do_cache=None):
        
        if do_cache is None: do_cache = self.opt.do_cache
        if do_cache: filename = f'{self.cachepath}/{self.opt.tag}_wave.npy'
        if do_cache and os.path.isfile(filename):
            z = np.load(filename)
        else:
            # A simplistic model of a wave using https://github.com/NeuralEnsemble/MotionClouds
            env = mc.envelope_gabor(self.fx, self.fy, self.ft, V_X=self.opt.V_Y, V_Y=self.opt.V_X, B_V=self.opt.B_V,
                                    sf_0=self.opt.sf_0, B_sf=self.opt.B_sf*self.opt.sf_0,
                                    theta=self.opt.theta, B_theta=self.opt.B_theta)
            # env /= env.mean()
            z = mc.random_cloud(env, seed=self.opt.seed)
            # print(z.max())
            if np.abs(z).max() > 0: 
                z = mc.rectif(z)
                # z = (.5* z/np.max(np.abs(z[:])) + .5)
            # print(z.max())

            # z *= np.linspace(self.opt.zmin, 1., self.opt.nx)[:, None, None] # [optional] vertical gradient
            if do_cache: np.save(filename, z)

        return z

    def get_filename(self, note=''):
        # output filename        
        md5 = hashlib.sha224((self.opt.figpath + self.opt.tag + note).encode()).hexdigest()[:8] # an unique identifier for future tagging
        output_filename = f'{self.opt.figpath}/{self.opt.tag}{note}_{md5}.{self.opt.ext}'
        return output_filename

    def transform(self, z_frame, modulation=1., lag_x=0., lag_y=0.):
        xv, yv = self.xv.copy(), self.yv.copy()

        # coords = np.vstack([(yv + lag_y).ravel(), (xv + lag_x).ravel()])
        # dzdx = ndimage.map_coordinates(dzdx, coords, order=1, mode='wrap').reshape(dzdx.shape)
        # dzdy = ndimage.map_coordinates(dzdy, coords, order=1, mode='wrap').reshape(dzdy.shape)
        

        # https://numpy.org/doc/stable/reference/generated/numpy.gradient.html
        # dzdx, dzdy = np.gradient(z_frame, edge_order=2)

        dzdx = ndimage.gaussian_filter(z_frame, self.opt.sigma, order=[1,0], mode='reflect')
        dzdy = ndimage.gaussian_filter(z_frame, self.opt.sigma, order=[0,1], mode='reflect')

        xv_warp = xv + modulation * self.opt.H * dzdx
        yv_warp = yv + modulation * self.opt.H * dzdy

        if self.opt.do_wrap:
            xv_warp = np.mod(xv_warp, 1)
            yv_warp = np.mod(yv_warp, self.ratio)

        return xv_warp, yv_warp

    def get_caustics(self, z_frame, image_aperture, modulation, rgb):

        xv, yv = self.transform(z_frame, modulation=modulation)

        if False:
            hist, _, _ = np.histogram2d(xv.ravel(), yv.ravel(),
                                        bins=[self.opt.nx//self.opt.bin_dens, self.opt.ny//self.opt.bin_dens],
                                        weights=image_aperture.ravel(),
                                        range=[[0, 1], [0, self.ratio]],
                                        density=True)
        else:
            # ---- version accélérée avec np.add.at ----
            nx = self.opt.nx // self.opt.bin_dens
            ny = self.opt.ny // self.opt.bin_dens
            hist = np.zeros((nx, ny), dtype=np.float64)

            ix = np.floor((xv.ravel() - 0) / 1.0 * nx).astype(np.int64)
            iy = np.floor((yv.ravel() - 0) / self.ratio * ny).astype(np.int64)

            # mask = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
            # np.add.at(hist, (ix[mask], iy[mask]), image_aperture.ravel()[mask])
            np.add.at(hist, (ix, iy), image_aperture.ravel())

        return hist[:, :, None] * rgb[None, None, :]


    def compute(self, z, image_aperture=None):
        """
        
        dpi: output resolution - sets the figure size as we ensure there is a one to one correspondance between pixels in the data and the output image
        """

        # 1/ do the raytracing of image through z:
        _, _, nframe = z.shape

        # if not specified, use a full image with full contrast (from 0=black to 1=white)
        if image_aperture is None: image_aperture = np.ones((self.opt.nx, self.opt.ny))

        #image_rgb = self.cs_srgb.spec_to_rgb(hist)
        image_rgb = np.zeros((self.opt.nx//self.opt.bin_dens,  self.opt.ny//self.opt.bin_dens, 3, nframe))
        for i_frame in trange(nframe, desc='Scanning frames', position=1, leave=True):
            z_frame = ndimage.zoom(z[:, :, i_frame], self.opt.bin_wave, mode='wrap', order=self.opt.bin_wave_order)

            if self.opt.n_jobs==1:
                # for i_i_wavelength, i_wavelength in enumerate(self.opt.bin_spectrum//2, self.N_wavelengths, self.opt.bin_spectrum):
                for i_wavelength in trange(self.opt.bin_spectrum//2, self.N_wavelengths, self.opt.bin_spectrum, desc='Scanning spectrum', position=0, leave=False):
                    modulation = 1. + self.opt.variation/2 - self.opt.variation*i_wavelength/self.N_wavelengths
                    hist_frame = self.get_caustics(z_frame, image_aperture, modulation, self.rgbs[i_wavelength])
                    # we add the monochromatique color to the image
                    image_rgb[:, :, :, i_frame] += hist_frame

            else:
                # -----  parallel map ------------------------------------------------
                wav_indices = range(self.opt.bin_spectrum//2, self.N_wavelengths, self.opt.bin_spectrum)
                contributions = Parallel(n_jobs=opt.n_jobs,
                                        backend='loky',
                                        loky_backend_kwargs={'timeout': 1800, 'max_nbytes': '1024M'}
                                        )(
                                        delayed(self.get_caustics)(
                                            z_frame    = z_frame,
                                            image_aperture      = image_aperture,
                                            modulation = 1. + self.opt.variation/2 - self.opt.variation*i_wavelength/self.N_wavelengths,
                                            rgb          = self.rgbs[i_wavelength])
                                        for i_wavelength in wav_indices)

                # -----  accumulate the partial results -------------------------------
                # contributions is a list of (H, W, 3) arrays → sum over the list
                image_rgb[:, :, :, i_frame] = np.sum(contributions, axis=0)   # shape (H, W, 3)

        return image_rgb

    def plot(self, z, image_aperture=None):
        output_filename = self.get_filename()
        if not(os.path.isfile(output_filename)):
            image_rgb = self.compute(z, image_aperture=image_aperture)
                
            # image_rgb -= image_rgb.min() # HACK
            image_rgb /= image_rgb.max()
            image_rgb = image_rgb ** (1/self.opt.gamma)

            # 2/ transform light into image:
            output_filename = make_movie(output_filename, (image_rgb*(2**self.opt.n_bits-1)).astype(self.np_dtype), fps=self.opt.fps)
        return output_filename

    def show(self, output_filename, width=1024):
        from IPython.display import HTML, Image, display
        if self.opt.nframe==1:
            # display(Image(url=output_filename.replace(self.opt.ext, 'png'), width=width))
            display(Image(url=output_filename, width=width))
        else:
            if self.opt.ext == 'gif':
                return display(Image(url=output_filename, width=width))
            else:
                #import moviepy.editor as mpy
                #return mpy.ipython_display(output_filename, width=width)
                # https://github.com/NeuralEnsemble/MotionClouds/blob/master/MotionClouds/MotionClouds.py#L858
                opts = ' loop="1" autoplay="1" controls '
                html = HTML(f'<video {opts} src="{output_filename}" type="video/mp4" width={width} >') # {self.opt.ext}
                html.reload()
                return display(html)

# %% [markdown]
# # une simple caustique
# ## génération de la vague

# %%
c = Caustique(init())

# %%
z = c.wave()
z.shape, z.min(), z.mean(), z.max()
# Out:
# ((1024, 1024, 192),
#  np.float64(0.07578219106628786),
#  np.float64(0.4999999999999997),
#  np.float64(1.0))

# %%
c.np_dtype
# Out:
# numpy.uint16

# %%
output_filename = c.get_filename(note='_vague')
if not(os.path.isfile(output_filename)):
    z_q = (z*(2**opt.n_bits-1)).astype(c.np_dtype)
    # z_q = ((z > 1)*(2**opt.n_bits-1)).astype(c.np_dtype)
    # print(z_q.shape, z_q.min(), z_q.mean(), z_q.max())
    output_filename = make_movie(output_filename, z_q[:, :, np.newaxis, :], fps=opt.fps)
    del z_q
c.show(output_filename)
# Out:
# <video  loop="1" autoplay="1" controls  src="2025-11-08_caustique-transition/trier_vague_2a0be498.mkv" type="video/mp4" width=1024 >

# %%
# %whos
# Out:
# Variable          Type                   Data/Info
# --------------------------------------------------
# CM_BY_INCH        float                  2.54
# Caustique         type                   <class '__main__.Caustique'>
# Lambda2color      type                   <class 'lambda2color.Lambda2color'>
# PRECISION         int                    12
# Parallel          type                   <class 'joblib.parallel.Parallel'>
# SubplotParams     type                   <class 'matplotlib.gridspec.SubplotParams'>
# c                 Caustique              <__main__.Caustique object at 0x11b541fd0>
# dataclass         function               <function dataclass at 0x105e09620>
# delayed           function               <function delayed at 0x11b532980>
# dpi               float                  52.0192
# get_ipython       function               <function get_ipython at 0x106794860>
# hashlib           module                 <module 'hashlib' from '/<...>b/python3.13/hashlib.py'>
# imageio           module                 <module 'imageio' from '/<...>ges/imageio/__init__.py'>
# init              type                   <class '__main__.init'>
# ip                ZMQInteractiveShell    <ipykernel.zmqshell.ZMQIn<...>ll object at 0x107c35d30>
# make_movie        function               <function make_movie at 0x107fd8ae0>
# matplotlib        module                 <module 'matplotlib' from<...>/matplotlib/__init__.py'>
# mc                module                 <module 'MotionClouds' fr<...>stiques/MotionClouds.py'>
# ndimage           module                 <module 'scipy.ndimage' f<...>ipy/ndimage/__init__.py'>
# np                module                 <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# opt               init                   init(figpath='2025-11-08_<...>=False, do_display=False)
# os                module                 <module 'os' (frozen)>
# output_filename   str                    2025-11-08_caustique-tran<...>/trier_vague_2a0be498.mkv
# planck            function               <function planck at 0x11b3d7420>
# plt               module                 <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# pprint            function               <function pprint at 0x105dcb9c0>
# scattering        function               <function scattering at 0x1191f6840>
# screen_size_cm    int                    100
# screen_size_in    float                  39.37007874015748
# shlex             module                 <module 'shlex' from '/op<...>lib/python3.13/shlex.py'>
# sp                module                 <module 'subprocess' from<...>ython3.13/subprocess.py'>
# study_name        str                    2025-11-08_caustique-transition
# subplotpars       SubplotParams          <matplotlib.gridspec.Subp<...>ms object at 0x11b541e80>
# tqdm              type                   <class 'tqdm.auto.tqdm'>
# trange            function               <function trange at 0x10841c400>
# xyz_from_xy       function               <function xyz_from_xy at 0x1191f76a0>
# z                 ndarray                1024x1024x192: 201326592 elems, type `float64`, 1610612736 bytes (1536.0 Mb)

# %% [markdown]
# ## génération de l'illumination

# %%
def generate_image(nx, ny, radius_in, radius_out):
    Y, X = np.meshgrid(np.linspace(-1, 1, ny, endpoint=True), np.linspace(-1, 1, nx, endpoint=True))
    image_aperture = (X**2 > radius_in**2)  # the horizontal band outside radius_in
    image_aperture *= (Y**2 < radius_out**2) # the vertical band inside radius_out
    image_aperture *= (X**2 < radius_out**2)  # the horizontal band inside radius_out
    return image_aperture*1.

image_aperture = generate_image(nx=opt.nx, ny=opt.ny, radius_in=opt.radius_in, radius_out=opt.radius_out)

fig, ax = plt.subplots(figsize=(opt.ny/opt.bin_dens/dpi, opt.nx/opt.bin_dens/dpi), subplotpars=subplotpars)

ax.imshow(image_aperture, cmap='gray');

# %%
image_aperture.min(), image_aperture.max(), opt.nx, opt.ny
# Out:
# (np.float64(0.0), np.float64(1.0), 4096, 4096)

# %%
# image_aperture = None

# %% [markdown]
# ## génération de la caustique

# %%
output_filename = c.plot(z, image_aperture)

# %%
c.show(output_filename)
# Out:
# <video  loop="1" autoplay="1" controls  src="2025-11-08_caustique-transition/trier_5ab3387c.mkv" type="video/mp4" width=1024 >

# %%
len(c.rgbs)
# Out:
# 40

# %% [markdown]
# # exploration des paramètres

# %%
N_scan = 0
base = 2

# %% [markdown]
# ## profondeur d'eau

# %%
for H_ in opt.H*np.logspace(-1, 1, N_scan, base=base):    
    c = Caustique(init(tag=f'{opt.tag}_H_{H_:.3f}', H = H_))
    output_filename = c.plot(z, image_aperture)
    print(f'H = {H_:.3f} -> {output_filename=} ')
    if opt.do_display: c.show(output_filename)

# %% [markdown]
# ## variation de l'indice de réfraction

# %%
# for variation_ in np.logspace(-2, 0, N_scan, base=10, endpoint=False):
#     opt = init()
#     c = Caustique(opt)
#     opt.variation = variation_
#     opt.tag = f'{opt.tag}_variation_{variation_:.3f}'

#     output_filename = c.plot(z, image_aperture)
#     print(f'variation = {variation_:.3f}  -> {output_filename=}')
#     if opt.do_display: c.show(output_filename)

# %% [markdown]
# ## post-processing

# %%
# for variable in ['gamma', 'min_lum', 'sigma']: 
for variable in ['gamma']: 
    print(f'======{variable}======')
    for modul in np.logspace(-1, 1, N_scan, base=base):
        c = Caustique(init(tag=f'{opt.tag}_{variable}_modul_{modul:.3f}'))
        c.d[variable] *= modul
        
        output_filename = c.plot(z, image_aperture)
        print(f'{variable}={variable}(default)*{modul:.3f}={c.d[variable]:.3E} -> {output_filename=}')
        if opt.do_display: c.show(output_filename)
# Out:
# ======gamma======

# %% [markdown]
# ## paramètres de l'ouverture

# %%
if opt.radius_in > 0:
    for radius_in in np.linspace(0, opt.radius_out, N_scan+1)[:-1]:
        c = Caustique(init(tag=f'{opt.tag}_image_{radius_in=:.3f}'))

        output_filename = c.plot(z, generate_image(nx=opt.nx, ny=opt.ny, radius_in=radius_in, radius_out=opt.radius_out))
        print(f'{radius_in=:.3f} -> {output_filename=} ')
        if opt.do_display: c.show(output_filename)

# %%
for radius_out in np.linspace(opt.radius_in, 1, N_scan+1)[1:]:
    c = Caustique(init(tag=f'{opt.tag}_image_{radius_out=:.3f}'))

    output_filename = c.plot(z, generate_image(nx=opt.nx, ny=opt.ny, radius_in=opt.radius_in, radius_out=radius_out))
    print(f'{radius_out=:.3f} -> {output_filename=} ')
    if opt.do_display: c.show(output_filename)

# %% [markdown]
# ## autres instances de l'onde

# %%
for seed_increment in range(N_scan):
    c = Caustique(init(tag=f'{opt.tag}_seed_{c.d['seed']}'))
    c.d['seed'] = c.d['seed'] + seed_increment
    output_filename = c.get_filename()
    if not(os.path.isfile(output_filename)):
        output_filename = c.plot(c.wave(do_cache=False), image_aperture)
    print(f'seed={c.d['seed']} -> {output_filename=}')
    if opt.do_display: c.show(output_filename)

# %% [markdown]
# ## autres variables sur l'onde

# %%
opt = init()
for variable in ['theta',  'B_theta', 'sf_0', 'B_V', 'B_sf', ]: #  'V_Y', 'V_X', , 'zmin'
    print(f'======{variable}======')
    for modul in np.logspace(-1, 1, N_scan, base=base):
        # del z
        # print(opt.tag, variable, modul, f'{opt.tag}_{variable}_modul_{modul:.3f}')
        c = Caustique(init(tag=f'{opt.tag}_{variable}_modul_{modul:.3f}'))
        c.d[variable] *= modul
        
        output_filename = c.get_filename()
        if not(os.path.isfile(output_filename)):
            z = c.wave(do_cache=False)
            print(z.shape, z.min(), z.mean(), z.max())
            output_filename = c.plot(z, image_aperture)
            print(z.shape, z.min(), z.mean(), z.max())
            # assert(output_filename == output_filename_)
        print(f'{variable}={variable}(default)*{modul:.3f}={c.d[variable]:.3E} -> {output_filename=}')
        if opt.do_display: c.show(output_filename)
# Out:
# ======theta======
# ======B_theta======
# ======sf_0======
# ======B_V======
# ======B_sf======

# %% [markdown]
# ## une longue vague

# %%
# %ls -lh {study_name}/longue*
# %ls -lh /tmp/{study_name}/longue*

# %%
# %rm -fr {study_name}/longue*
# %rm -fr ~/tmp/{study_name}/longue*

# %%
print('====== long wave ======')
c = Caustique(init(tag='longue'))
c.opt
# Out:
# ====== long wave ======
# init(figpath='2025-11-08_caustique-transition', phi=1.61803, tag='longue', ext='mkv', nx=4096, ny=4096, nframe=192, bin_dens=2, bin_wave=4, bin_wave_order=2, bin_spectrum=2, seed=2025, H=30.0, variation=0.2, sigma=1.0, sf_0=0.002197265625, B_sf=1.2, V_Y=0.1, V_X=0.382, B_V=1.0, theta=1.5707963267948966, B_theta=1.064650843716541, radius_in=0.0, radius_out=0.8, do_wrap=True, n_bits=16, n_jobs=-1, gamma=2.4, fps=24, do_cache=True, verbose=False, do_display=False)

# %%
# N_wave = 4 * PRECISION
# N_wave = 5
N_wave = 25
N_wave = 40
# N_wave = 75
kappa = .5 # dispersion of the modulation
amplitude = np.exp(kappa * (np.cos((np.linspace(0, 1, N_wave)-.50)*2*np.pi) -1) )
modul = 0.5
kappa = 2.5 # dispersion of the modulation
B_Vs = c.opt.B_V * ( 1 + modul * np.exp(kappa * (np.cos((np.linspace(0, 1, N_wave)-.25)*2*np.pi) -1) ))
B_sfs = c.opt.B_sf * ( 1 + modul * np.exp(kappa * (np.cos((np.linspace(0, 1, N_wave)-.50)*2*np.pi) -1) ))
B_thetas = c.opt.B_theta / ( 1 + modul * np.exp(kappa * (np.cos((np.linspace(0, 1, N_wave)-.75)*2*np.pi) -1) ))
# sf_0s = c.opt.sf_0 / ( 1 + modul * np.exp(kappa * (np.cos((np.linspace(0, 1, N_wave)-.75)*2*np.pi) ) ))

# %%
fig, ax = plt.subplots(4, 1, figsize=(8, 8))
ax[0].plot(amplitude)
ax[0].set_title('Amplitude')
ax[0].set_xticks([])
ax[1].plot(B_thetas)
ax[1].set_title('B_theta')
ax[1].set_xticks([])
ax[2].plot(B_sfs)
ax[2].set_title('B_sfs')
ax[2].set_xticks([])
ax[3].plot(B_Vs)
ax[3].set_title('B_V')
# ax[3].plot(sf_0s)
# ax[3].set_title('sf_0')
plt.show()

# %%
c_chunk = Caustique(init())
# print(f'{c.cachepath}/{c.opt.tag}_vague-smooth_0.npy')
if not(os.path.isfile(f'{c.cachepath}/{c.opt.tag}_vague-smooth_0.npy')):
    print('Computing waves...')
    # z_updates = []
    for i_wave in trange(N_wave):
        fname = f'{c.cachepath}/{c.opt.tag}_vague_{i_wave}.npy'
        if not(os.path.isfile(fname)):
            #     z_update = np.load(fname)
            # else:        
            # c_chunk = Caustique(init())
            c_chunk.opt.B_sf = B_sfs[i_wave]
            c_chunk.opt.B_theta = B_thetas[i_wave]
            # c_chunk.opt.sf_0 = sf_0s[i_wave]
            c_chunk.opt.B_V = B_Vs[i_wave]
            c_chunk.opt.seed = opt.seed + i_wave

            z_update = amplitude[i_wave] * c_chunk.wave(do_cache=False)
            np.save(fname, z_update)
        # z_updates.append(z_update)

smooth = (c_chunk.ft - c_chunk.ft.min())/(c_chunk.ft.max() - c_chunk.ft.min()) # smoothly progress from 0. to 1.
del c_chunk
# z = np.zeros((opt.nx, opt.ny, 0))
for i_wave in trange(N_wave):
    fname = f'{c.cachepath}/{c.opt.tag}_vague-smooth_{i_wave}.npy'

    if not(os.path.isfile(fname)):
        z_previous_update = np.load(f'{c.cachepath}/{c.opt.tag}_vague_{(i_wave-1) % N_wave}.npy')
        z_update = np.load(f'{c.cachepath}/{c.opt.tag}_vague_{i_wave}.npy')
        z_smooth = (1.-smooth)*z_previous_update + smooth*z_update
        # z = np.concatenate((z, z_smooth), axis=-1)
        np.save(fname, z_smooth)

        del z_previous_update
        del z_smooth
        del z_update
del smooth
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 73103.34it/s]

# %%
print(c.opt)
# Out:
# init(figpath='2025-11-08_caustique-transition', phi=1.61803, tag='longue', ext='mkv', nx=4096, ny=4096, nframe=192, bin_dens=2, bin_wave=4, bin_wave_order=2, bin_spectrum=2, seed=2025, H=30.0, variation=0.2, sigma=1.0, sf_0=0.002197265625, B_sf=1.2, V_Y=0.1, V_X=0.382, B_V=1.0, theta=1.5707963267948966, B_theta=1.064650843716541, radius_in=0.0, radius_out=0.8, do_wrap=True, n_bits=16, n_jobs=-1, gamma=2.4, fps=24, do_cache=True, verbose=False, do_display=False)

# %%
# z.shape, z.min(), z.mean(), z.max()

# %%
# %whos
# Out:
# Variable          Type                   Data/Info
# --------------------------------------------------
# B_Vs              ndarray                40: 40 elems, type `float64`, 320 bytes
# B_sfs             ndarray                40: 40 elems, type `float64`, 320 bytes
# B_thetas          ndarray                40: 40 elems, type `float64`, 320 bytes
# CM_BY_INCH        float                  2.54
# Caustique         type                   <class '__main__.Caustique'>
# Lambda2color      type                   <class 'lambda2color.Lambda2color'>
# N_scan            int                    0
# N_wave            int                    40
# PRECISION         int                    12
# Parallel          type                   <class 'joblib.parallel.Parallel'>
# SubplotParams     type                   <class 'matplotlib.gridspec.SubplotParams'>
# amplitude         ndarray                40: 40 elems, type `float64`, 320 bytes
# ax                ndarray                4: 4 elems, type `object`, 32 bytes
# base              int                    2
# c                 Caustique              <__main__.Caustique object at 0x11b7802d0>
# dataclass         function               <function dataclass at 0x105e09620>
# delayed           function               <function delayed at 0x11b532980>
# dpi               float                  52.0192
# fig               Figure                 Figure(800x800)
# fname             str                    /Users/laurent/tmp/2025-1<...>ongue_vague-smooth_39.npy
# generate_image    function               <function generate_image at 0x11b681d00>
# get_ipython       function               <function get_ipython at 0x106794860>
# hashlib           module                 <module 'hashlib' from '/<...>b/python3.13/hashlib.py'>
# i_wave            int                    39
# image_aperture    ndarray                4096x4096: 16777216 elems, type `float64`, 134217728 bytes (128.0 Mb)
# imageio           module                 <module 'imageio' from '/<...>ges/imageio/__init__.py'>
# init              type                   <class '__main__.init'>
# ip                ZMQInteractiveShell    <ipykernel.zmqshell.ZMQIn<...>ll object at 0x107c35d30>
# kappa             float                  2.5
# make_movie        function               <function make_movie at 0x107fd8ae0>
# matplotlib        module                 <module 'matplotlib' from<...>/matplotlib/__init__.py'>
# mc                module                 <module 'MotionClouds' fr<...>stiques/MotionClouds.py'>
# modul             float                  0.5
# ndimage           module                 <module 'scipy.ndimage' f<...>ipy/ndimage/__init__.py'>
# np                module                 <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# opt               init                   init(figpath='2025-11-08_<...>=False, do_display=False)
# os                module                 <module 'os' (frozen)>
# output_filename   str                    2025-11-08_caustique-tran<...>sition/trier_5ab3387c.mkv
# planck            function               <function planck at 0x11b3d7420>
# plt               module                 <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# pprint            function               <function pprint at 0x105dcb9c0>
# scattering        function               <function scattering at 0x1191f6840>
# screen_size_cm    int                    100
# screen_size_in    float                  39.37007874015748
# shlex             module                 <module 'shlex' from '/op<...>lib/python3.13/shlex.py'>
# sp                module                 <module 'subprocess' from<...>ython3.13/subprocess.py'>
# study_name        str                    2025-11-08_caustique-transition
# subplotpars       SubplotParams          <matplotlib.gridspec.Subp<...>ms object at 0x11b541e80>
# tqdm              type                   <class 'tqdm.auto.tqdm'>
# trange            function               <function trange at 0x10841c400>
# variable          str                    B_sf
# xyz_from_xy       function               <function xyz_from_xy at 0x1191f76a0>
# z                 ndarray                1024x1024x192: 201326592 elems, type `float64`, 1610612736 bytes (1536.0 Mb)

# %%
output_filename = c.get_filename(note='_vague')
# if not(os.path.isfile(output_filename)):

    # with imageio.v2.get_writer(
    #     output_filename,
    #     format='FFmpeg', 
    #     mode='I',
    #     # format='av', 
    #     fps=opt.fps,
    #     # pixelformat=pix_fmt
    #     # codec='ffv1',  # Use FFV1 for lossless compression
    #     ) as writer:

    #     for i_wave in trange(N_wave, desc='Generating movie'):
    #         z_smooth = np.load(f'{c.cachepath}/{c.opt.tag}_vague-smooth_{i_wave}.npy')
    
    #         for i_frame in range(z_smooth.shape[-1]):
    #             # Append the frame to the video writer
    #             writer.append_data((z_smooth[..., i_frame]*(2**c.opt.n_bits-1)).astype(c.np_dtype))

            
                
    # z_q = (z*(2**c.opt.n_bits-1)).astype(c.np_dtype)
    # print(z_q.shape, z_q.min(), z_q.mean(), z_q.max())
    # output_filename = make_movie(output_filename, z_q, fps=opt.fps)

if not(os.path.isfile(output_filename)):

    all_frames = np.zeros((c.opt.nx//c.opt.bin_wave, c.opt.ny//c.opt.bin_wave, 0), dtype=c.np_dtype)
    for i_wave in trange(N_wave, desc='Generating movie'):
        fname = f'{c.cachepath}/{c.opt.tag}_vague-smooth_{i_wave}.npy'
        frames = np.load(fname)
        frames = (frames*(2**c.opt.n_bits-1)).astype(c.np_dtype)
        all_frames = np.concatenate((all_frames, frames), axis=-1)
    output_filename = make_movie(output_filename, all_frames[:, :, np.newaxis, :]*np.ones((1, 1, 3, 1), dtype=c.np_dtype), fps=opt.fps)

    del frames
    del all_frames

c.show(output_filename)
# Out:
# <video  loop="1" autoplay="1" controls  src="2025-11-08_caustique-transition/longue_vague_e66eb70e.mkv" type="video/mp4" width=1024 >

# %%
# output_filename = make_movie(output_filename, all_frames[:, :, np.newaxis, :]*np.ones((1, 1, 3, 1), dtype=c.np_dtype), fps=opt.fps)

# %%
# for i_wave in trange(N_wave):
#     fname = f'{c.cachepath}/{c.opt.tag}_vague_{i_wave}.npy'
#     os.remove(fname)

# %% [markdown]
# ## la caustique de la longue vague

# %%
image_rgb_max = 0.
for i_wave in trange(N_wave, desc='Scanning blocks'):
    fname = f'{c.cachepath}/{c.opt.tag}_caustique_{i_wave}.npy'
    if os.path.isfile(fname):
        image_update = np.load(fname)
    else:
        z_smooth = np.load(f'{c.cachepath}/{c.opt.tag}_vague-smooth_{i_wave}.npy')
        image_update = c.compute(z_smooth, image_aperture)
        np.save(fname, image_update)
        del z_smooth 
    
    image_rgb_max = max(image_rgb_max, image_update.max())    
    del image_update
print(f'{image_rgb_max=}')
# Out:
# Scanning frames: 100%|██████████| 192/192 [23:41<00:00,  7.40s/it]
# Scanning frames: 100%|██████████| 192/192 [23:33<00:00,  7.36s/it]
# Scanning frames: 100%|██████████| 192/192 [23:45<00:00,  7.43s/it]
# Scanning blocks: 100%|██████████| 40/40 [1:13:07<00:00, 109.69s/it]
# image_rgb_max=np.float64(31797.9621713962)

# %%
# %whos

# %%
output_filename = c.get_filename(note='_caustique')
# if not(os.path.isfile(output_filename)):

#     with imageio.v2.get_writer(
#         output_filename,
#         format='FFmpeg', 
#         mode='I',
#         # format='av', 
#         fps=opt.fps,
#         # pixelformat=pix_fmt
#         # codec='ffv1',  # Use FFV1 for lossless compression
#         ) as writer:

#         for i_wave in trange(N_wave, desc='Generating movie'):
#             fname = f'{c.cachepath}/{c.opt.tag}_caustique_{i_wave}.npy'
#             frames = np.load(fname)

#             frames /= image_rgb_max
#             frames = frames ** (1/opt.gamma)

#             for i_frame in range(frames.shape[-1]):
#                 # Append the frame to the video writer
#                 writer.append_data((frames[..., i_frame]*(2**c.opt.n_bits-1)).astype(c.np_dtype))
if not(os.path.isfile(output_filename)):

    all_frames = np.zeros((c.opt.nx//c.opt.bin_dens, c.opt.ny//c.opt.bin_dens, 3, 0), dtype=c.np_dtype)
    for i_wave in trange(N_wave, desc='Generating movie'):
        fname = f'{c.cachepath}/{c.opt.tag}_caustique_{i_wave}.npy'
        frames = np.load(fname)

        frames /= image_rgb_max
        frames = frames ** (1/opt.gamma)
        frames = (frames*(2**c.opt.n_bits-1)).astype(c.np_dtype)

        all_frames = np.concatenate((all_frames, frames), axis=-1)
        # print(all_frames.shape)
    del frames

    output_filename = make_movie(output_filename, all_frames, fps=opt.fps)
c.show(output_filename)
# Out:
# Generating movie:   2%|▎         | 1/40 [00:18<11:55, 18.35s/it]
# (2048, 2048, 3, 192)
# Generating movie:   5%|▌         | 2/40 [00:37<11:58, 18.91s/it]
# (2048, 2048, 3, 384)
# Generating movie:   8%|▊         | 3/40 [00:57<11:54, 19.30s/it]
# (2048, 2048, 3, 576)
# Generating movie:  10%|█         | 4/40 [01:17<11:44, 19.56s/it]
# (2048, 2048, 3, 768)
# Generating movie:  12%|█▎        | 5/40 [01:38<11:38, 19.96s/it]
# (2048, 2048, 3, 960)
# Generating movie:  15%|█▌        | 6/40 [01:58<11:24, 20.13s/it]
# (2048, 2048, 3, 1152)
# Generating movie:  18%|█▊        | 7/40 [02:19<11:11, 20.35s/it]
# (2048, 2048, 3, 1344)
# Generating movie:  20%|██        | 8/40 [02:40<11:00, 20.64s/it]
# (2048, 2048, 3, 1536)
# Generating movie:  22%|██▎       | 9/40 [03:02<10:48, 20.93s/it]
# (2048, 2048, 3, 1728)
# Generating movie:  25%|██▌       | 10/40 [03:24<10:37, 21.25s/it]
# (2048, 2048, 3, 1920)
# Generating movie:  28%|██▊       | 11/40 [03:46<10:25, 21.58s/it]
# (2048, 2048, 3, 2112)
# Generating movie:  30%|███       | 12/40 [04:09<10:14, 21.96s/it]
# (2048, 2048, 3, 2304)
# Generating movie:  32%|███▎      | 13/40 [04:32<10:01, 22.26s/it]
# (2048, 2048, 3, 2496)
# Generating movie:  35%|███▌      | 14/40 [04:55<09:46, 22.56s/it]
# (2048, 2048, 3, 2688)
# Generating movie:  38%|███▊      | 15/40 [05:19<09:31, 22.86s/it]
# (2048, 2048, 3, 2880)
# Generating movie:  40%|████      | 16/40 [05:42<09:16, 23.18s/it]
# (2048, 2048, 3, 3072)
# Generating movie:  42%|████▎     | 17/40 [06:07<09:00, 23.49s/it]
# (2048, 2048, 3, 3264)
# Generating movie:  45%|████▌     | 18/40 [06:31<08:44, 23.84s/it]
# (2048, 2048, 3, 3456)
# Generating movie:  48%|████▊     | 19/40 [06:56<08:28, 24.22s/it]
# (2048, 2048, 3, 3648)
# Generating movie:  50%|█████     | 20/40 [07:22<08:11, 24.58s/it]
# (2048, 2048, 3, 3840)
# Generating movie:  52%|█████▎    | 21/40 [07:48<07:54, 24.95s/it]
# (2048, 2048, 3, 4032)
# Generating movie:  55%|█████▌    | 22/40 [08:14<07:34, 25.27s/it]
# (2048, 2048, 3, 4224)
# Generating movie:  57%|█████▊    | 23/40 [08:40<07:14, 25.56s/it]
# (2048, 2048, 3, 4416)
# Generating movie:  60%|██████    | 24/40 [09:07<06:55, 25.99s/it]
# (2048, 2048, 3, 4608)
# Generating movie:  62%|██████▎   | 25/40 [09:34<06:36, 26.44s/it]
# (2048, 2048, 3, 4800)
# Generating movie:  65%|██████▌   | 26/40 [10:02<06:16, 26.90s/it]
# (2048, 2048, 3, 4992)
# Generating movie:  68%|██████▊   | 27/40 [10:31<05:55, 27.35s/it]
# (2048, 2048, 3, 5184)
# Generating movie:  70%|███████   | 28/40 [11:00<05:33, 27.80s/it]
# (2048, 2048, 3, 5376)
# Generating movie:  72%|███████▎  | 29/40 [11:29<05:11, 28.29s/it]
# (2048, 2048, 3, 5568)
# Generating movie:  75%|███████▌  | 30/40 [11:59<04:48, 28.85s/it]
# (2048, 2048, 3, 5760)
# Generating movie:  78%|███████▊  | 31/40 [12:30<04:23, 29.31s/it]
# (2048, 2048, 3, 5952)
# Generating movie:  80%|████████  | 32/40 [13:01<03:58, 29.82s/it]
# (2048, 2048, 3, 6144)
# Generating movie:  82%|████████▎ | 33/40 [13:32<03:31, 30.26s/it]
# (2048, 2048, 3, 6336)
# Generating movie:  85%|████████▌ | 34/40 [14:04<03:04, 30.70s/it]
# (2048, 2048, 3, 6528)
# Generating movie:  88%|████████▊ | 35/40 [14:36<02:36, 31.20s/it]
# (2048, 2048, 3, 6720)
# Generating movie:  90%|█████████ | 36/40 [15:09<02:06, 31.68s/it]
# (2048, 2048, 3, 6912)
# Generating movie:  92%|█████████▎| 37/40 [15:42<01:36, 32.15s/it]
# (2048, 2048, 3, 7104)
# Generating movie:  95%|█████████▌| 38/40 [16:16<01:05, 32.63s/it]
# (2048, 2048, 3, 7296)
# Generating movie:  98%|█████████▊| 39/40 [16:50<00:33, 33.11s/it]
# (2048, 2048, 3, 7488)
# Generating movie: 100%|██████████| 40/40 [17:25<00:00, 26.13s/it]
# (2048, 2048, 3, 7680)
# 2048 2048 3 7680
# Encoding frames: 100%|██████████| 7680/7680 [40:34<00:00,  3.15it/s]
# <video  loop="1" autoplay="1" controls  src="2025-11-08_caustique-transition/longue_caustique_5dbd9fe3.mkv" type="video/mp4" width=1024 >

# %%
print(output_filename)
# Out:
# 2025-11-08_caustique-transition/longue_caustique_5dbd9fe3.mkv

# %% [markdown]
# Voilà !
