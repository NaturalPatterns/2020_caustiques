# %% [markdown]
# # Caustiques

# %%
# %pip install -q -U -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import cv2
from tqdm.auto import trange, tqdm
import matplotlib
# import matplotlib.gridspec as gs
from matplotlib.gridspec import SubplotParams
import numpy as np
matplotlib.__version__
# Out:
# '3.10.7'

# %%
import os 
from IPython import get_ipython
ip = get_ipython()
# print(ip.user_ns)
study_name = None
if '__vsc_ipynb_file__' in ip.user_ns:
    # https://github.com/msm1089/ipynbname/issues/17
    study_name = os.path.split(os.path.basename(ip.user_ns['__vsc_ipynb_file__']))[1]
elif '__file__' in ip.user_ns:
    study_name = ip.user_ns['__file__']
else:
    import ipynbname
    study_name = ipynbname.name()
study_name = study_name.replace('.ipynb', '')
study_name
# Out:
# '2025-10-21_caustique-transition'

# %%
# the higher PRECISION, the bigger the file
PRECISION = 4  # debugging
PRECISION = 8 # low quality
PRECISION = 10 # medium quality
# PRECISION = 12 # good quality
# PRECISION = 14 # very good quality
# PRECISION = 15 # for production

# https://docs.python.org/3/library/dataclasses.html?highlight=dataclass#module-dataclasses
from dataclasses import dataclass

@dataclass
class init:
    figpath: str = study_name # Folder to store images
    phi: float = 1.61803 # beauty is gold
    tag: str = 'caustique' # Tag
    ext: str = 'mp4' # Extension for output
    nx: int = 1*2**PRECISION # number of pixels (vertical)
    ny: int = 1*2**PRECISION # number of pixels (horizontal)
    nframe: int = 24*4 # number of frames for each chunk
    bin_dens: int = 1 # relative bin density
    bin_spectrum: int = 4 # bin spacing in spectrum (lower is more CPU)
    seed: int = 2025 # seed for RNG
    H: float = 40.0 # depth of the pool
    variation: float = .20 # variation of diffraction index: http://www.philiplaven.com/p20.html 1.40 at 400 nm and 1.37 at 700nm makes a 2% variation
    scale: float = .618*nx # period in pixels
    B_sf: float = 1.61 # bandwidth in sf
    V_Y: float = 0.3 # horizontal speed
    V_X: float = 0.3 # vertical speed
    B_V: float = 1.0 # bandwidth in speed
    zmin: float = 1.0 # relative minimal value of wave height at the top to generate a gradient (set to 1. to have no gradient)
    # theta: float = 2*np.pi*(2-1.61803) # angle with the horizontal
    theta: float = np.pi/2 # angle with the horizontal
    B_theta: float = 60*np.pi/180 # bandwidth in theta
    min_lum: float = .01 # global diffusion level for the rendering giving the pedestal value
    n_bits: int = 8 # bits to save images
    gamma: float = 4. # Gamma exponant to convert luminosity to luminance
    fps: float = 24 # frames per second
    do_cache: bool = True # Cache intermediate output.
    verbose: bool = False # Displays more verbose output.
    do_display: bool = False # Displays images in notebook.
    do_recompute: bool = False # Restart each computation

# %%
opt = init()
print(f'Saving our simulations in={opt.figpath}')
# Out:
# Saving our simulations in=2025-10-21_caustique-transition

# %%
# if opt.nframe==1: opt.ext = 'png'

# %%
from pprint import pprint
pprint(opt)
# Out:
# init(figpath='2025-10-21_caustique-transition',
#      phi=1.61803,
#      tag='caustique',
#      ext='mp4',
#      nx=1024,
#      ny=1024,
#      nframe=96,
#      bin_dens=1,
#      bin_spectrum=4,
#      seed=2025,
#      H=40.0,
#      variation=0.2,
#      scale=632.832,
#      B_sf=1.61,
#      V_Y=0.3,
#      V_X=0.3,
#      B_V=1.0,
#      zmin=1.0,
#      theta=1.5707963267948966,
#      B_theta=1.0471975511965976,
#      min_lum=0.01,
#      n_bits=8,
#      gamma=4.0,
#      fps=24,
#      do_cache=True,
#      verbose=False,
#      do_display=False,
#      do_recompute=False)

# %%
screen_size_cm = 100 # cm
CM_BY_INCH = 2.54 # this is a constant
screen_size_in = screen_size_cm/CM_BY_INCH
dpi = (opt.nx // opt.bin_dens) / screen_size_in
print(f'Screen size={screen_size_cm}cm={screen_size_in:.3f}in, dpi={dpi:.0f}dpi')
# Out:
# Screen size=100cm=39.370in, dpi=26dpi

# %% [markdown]
# ## utilitaires
#
# Transformation d'une séquence de trames PNG en gif ou mkv:

# %%
import imageio
# def make_gif(gifname, fnames, fps, do_delete=True):
#     with imageio.get_writer(gifname, mode='I', fps=fps) as writer:
#         for fname in fnames:
#             writer.append_data(imageio.imread(fname))

#     from pygifsicle import optimize
#     optimize(str(gifname))
#     if do_delete: 
#         for fname in fnames: os.remove(fname)
#     return gifname

# https://moviepy.readthedocs.io/en/latest/getting_started/videoclips.html#imagesequenceclip
# def make_mp4(mkvname, fnames, fps, do_delete=True):
#     import moviepy.editor as mpy
#     clip = mpy.ImageSequenceClip(fnames, fps=fps)
#     clip.write_videofile(mkvname, fps=fps, codec='libx264', verbose=False, logger=None)
#     if do_delete: 
#         for fname in fnames: os.remove(fname)
#     return mkvname 

# from tqdm import tqdm
# from tqdm.notebook import tqdm
# def make_mp4(moviename, fnames, fps):
#     """Create an mkv video from a sequence of image files.

#     Args:
#         moviename (str): Path to the output video file.
#         fnames (list): List of paths to input image files.
#         fps (int): Frames per second for the output video.

#     Returns:
#         str: Path to the created video file.
#     """
#     ffmpeg_params = [
#         "-c:v", "ffv1",                # codec (ffv1 = lossless intra‑frame)
#         "-level", "3",                # highest ffv1 quality level
#         "-pix_fmt", "rgb48le",          # 16‑bit pixel format     pix_fmt: str = "gray16le",   # 16‑bit grayscale, change to "rgb48le" for color
#         "-preset", "veryslow",        # optional – best compression, slower
#     ]
#     with imageio.v2.get_writer(
#         moviename,
#         fps=fps,
#         macro_block_size=1,
#         ffmpeg_log_level="error",   # keep the console tidy
#         # ffmpeg_params=ffmpeg_params,
#     ) as writer:    
#         for fname in tqdm(fnames, desc="Creating video"):
#             print('>>>', fname)
#             frame = imageio.v2.imread(fname, pilmode='I;16')
#             print('bip')
#             frame = frame.astype(np.uint16)
#             writer.append_data(frame)
#     return moviename

def make_mp4(moviename, frames, fps):
    with imageio.v2.get_writer(
        moviename,
        format='FFmpeg', 
        # mode='I',
        # format='av', 
        fps=fps,
        # pixelformat=pix_fmt
        # codec='ffv1',  # Use FFV1 for lossless compression
        ) as writer:
        for i_frame in range(frames.shape[-1]):
            # Append the frame to the video writer
            writer.append_data(frames[..., i_frame])
    return moviename

# import imageio.v3 as iio
# def make_mp4(mkvname, frames, fps):
#     pix_fmt = 'rgb48le' if frames.ndim==3 else 'gray16le'
#     iio.imwrite(
#         mkvname,
#         np.moveaxis(frames, -1, 0),
#         plugin='pyav',
#         codec='ffv1',
#         fps=fps,
#         in_pixel_format=pix_fmt,
#         out_pixel_format=pix_fmt
#     )
#     return mkvname

# %%
# import numpy as np
# import imageio

# # Define video parameters
# width, height, fps = 640, 480, 30
# num_frames = fps*2

# # Create a video writer object with the desired parameters
# output_file = "output_video.mp4"
#     # pix_fmt = 'rgb48le' if frames.ndim==3 else 'gray16le'
#     # iio.imwrite(
#     #     mkvname,
#     #     np.moveaxis(frames, -1, 0),
#     #     plugin='pyav',
#     #     codec='ffv1',
# pix_fmt = 'rgb48le'
# pix_fmt = 'gray16le'

# with imageio.v2.get_writer(
#     output_file,
#     # format='FFmpeg', mode='I',
#     # format='av', 
#     fps=fps,
#     pixelformat=pix_fmt
#     # codec='ffv1',  # Use FFV1 for lossless compression
#     ) as writer:
#     for _ in range(num_frames):
#         # Generate a random 16-bit frame
#         frame = np.random.randint(0, 2**8-1, (height, width), dtype=np.uint8)
#         # Append the frame to the video writer
#         writer.append_data(frame)

# print(f"Video saved as {output_file}")

# make_mp4("output_video.mp4", np.random.randint(0, 2**8-1, (640, 480, 30), dtype=np.uint8), fps=24)

# %% [markdown]
# Utilities to compute the spectrum of the blue sky and convert them later to RGB values (check out https://laurentperrinet.github.io/sciblog/posts/2020-07-04-colors-of-the-sky.html for details)

# %%
from lambda2color import Lambda2color, xyz_from_xy

# borrowed from https://github.com/gummiks/gummiks.github.io/blob/master/scripts/astro/planck.py
def planck(wav, T):
    import scipy.constants as const
    c = const.c # c = 3.0e+8
    h = const.h # h = 6.626e-34
    k = const.k # k = 1.38e-23
    a = 2.0*h*c**2
    b = h*c/(wav*k*T)
    intensity = a / ( (wav**5) * (np.exp(b) - 1.0) )
    return intensity

def scattering(wav, a=0.005, p=1.3, b=0.45):
    """
    b is  proportionate  to  the  column  density  of  aerosols
    along  the  path  of  sunlight,  from  outside  the  atmosphere
    to  the  point  of  observation
    
    see https://laurentperrinet.github.io/sciblog/posts/2020-07-04-colors-of-the-sky.html for more details

    """
    # converting wav in µm:
    intensity = np.exp(-a/((wav/1e-6)**4)) # Rayleigh extinction by nitrogen
    intensity *= (wav/1e-6)**-4
    intensity *= np.exp(-b/((wav/1e-6)**p)) # Aerosols
    return intensity

# %% [markdown]
# ## calcul des caustiques

# %%
import matplotlib
subplotpars = SubplotParams(left=0., right=1., bottom=0., top=1., wspace=0., hspace=0.)
import matplotlib.pyplot as plt
import shutil
import hashlib
import MotionClouds as mc

class Caustique:
    def __init__(self, opt):
        """
        Image coordinates follow 'ij' indexing, that is,
        * their origin at the top left,
        * the X axis is vertical and goes "down",
        * the Y axis is horizontal and goes "right".

        """
        self.mc = mc
        self.ratio = opt.ny/opt.nx # ratio between height and width (>1 for portrait, <1 for landscape)
        X = np.linspace(0, 1, opt.nx, endpoint=False) # vertical
        Y = np.linspace(0, self.ratio, opt.ny, endpoint=False) # horizontal
        self.xv, self.yv = np.meshgrid(X, Y, indexing='ij')
        self.opt = opt
        # https://stackoverflow.com/questions/16878315/what-is-the-right-way-to-treat-python-argparse-namespace-as-a-dictionary
        self.d = vars(opt)
        os.makedirs(self.opt.figpath, exist_ok=True)
        self.cachepath = os.path.join('/tmp', self.opt.figpath)
        if opt.verbose: print(f'{self.cachepath=}')
        os.makedirs(self.cachepath, exist_ok=True)

        
        illuminant = xyz_from_xy(0.3127, 0.3291) # a standard white
        # illuminant = xyz_from_xy(0.268375 0.283377) # sky
        # illuminant = xyz_from_xy(0.325998, 0.335354) # sun

        # color conversion class
        self.cs_srgb = Lambda2color(red=xyz_from_xy(0.64, 0.33),
                                    green=xyz_from_xy(0.30, 0.60),
                                    blue=xyz_from_xy(0.15, 0.06),
                                    white=illuminant)
        
        self.wavelengths = self.cs_srgb.cmf[:, 0]*1e-9
        self.N_wavelengths = len(self.wavelengths)
        # multiply by the spectrum of the sky
        intensity5800 = planck(self.wavelengths, 5800.)
        scatter = scattering(self.wavelengths)
        self.spectrum_sky = intensity5800 * scatter
        self.spectrum_sky /= self.spectrum_sky.max()

    def wave(self, do_cache=None):
        if do_cache is None: do_cache = self.opt.do_cache
        if do_cache: filename = f'{self.cachepath}/{self.opt.tag}_wave.npy'
        if do_cache and os.path.isfile(filename) and not(self.opt.do_recompute):
                z = np.load(filename)
        else:
            # A simplistic model of a wave using https://github.com/NeuralEnsemble/MotionClouds
            fx, fy, ft = mc.get_grids(self.opt.nx, self.opt.ny, self.opt.nframe)
            env = mc.envelope_gabor(fx, fy, ft, V_X=self.opt.V_Y, V_Y=self.opt.V_X, B_V=self.opt.B_V,
                                    sf_0=1./self.opt.scale, B_sf=self.opt.B_sf/self.opt.scale,
                                    theta=self.opt.theta, B_theta=self.opt.B_theta)
            z = mc.random_cloud(env, seed=self.opt.seed)
            if np.max(np.abs(z))>0: z = mc.rectif(z)
            z *= np.linspace(self.opt.zmin, 1., self.opt.nx)[:, None, None] # [optional] vertical gradient
            if do_cache: np.save(filename, z)
        return z

    def transform(self, z_, modulation=1., edge_order=2):
        xv, yv = self.xv.copy(), self.yv.copy()

        # https://numpy.org/doc/stable/reference/generated/numpy.gradient.html
        dzdx, dzdy = np.gradient(z_, edge_order=edge_order)

        xv = xv + modulation * self.opt.H * dzdx
        yv = yv + modulation * self.opt.H * dzdy

        xv = np.mod(xv, 1)
        yv = np.mod(yv, self.ratio)

        return xv, yv

    def get_filename(self):
        # output filename        
        md5 = hashlib.sha224((self.opt.figpath + self.opt.tag).encode()).hexdigest()[:8] # an unique identifier for future tagging
        output_filename = f'{self.opt.figpath}/{self.opt.tag}_{md5}.{self.opt.ext}'
        return output_filename

    # def make_frames(self, image_rgb, output_filename):
    #     nframe = image_rgb.shape[-1]
    #     fnames = []
    #     for i_frame in trange(nframe):
    #         # fig, ax = plt.subplots(figsize=(self.opt.ny/self.opt.bin_dens/dpi, self.opt.nx/self.opt.bin_dens/dpi), subplotpars=subplotpars)
    #         # if self.opt.multispectral:
    #         #     image_array = image_rgb[:, :, :, i_frame] ** (1/self.opt.gamma)
    #         #     ax.imshow(image_array, vmin=0, vmax=1)
    #         # else:
    #         #     if do_color: # the following code is not used anymore
    #         #         bluesky = np.array([0.268375, 0.283377]) # xyz
    #         #         sun = np.array([0.325998, 0.335354]) # xyz
    #         #         # ax.pcolormesh(edge_y, edge_x, hist[:, :, i_frame], vmin=0, vmax=1, cmap=plt.cm.Blues_r)
    #         #         # https://en.wikipedia.org/wiki/CIE_1931_color_space#Mixing_colors_specified_with_the_CIE_xy_chromaticity_diagram
    #         #         L1 = 1 - hist[:, :, i_frame]
    #         #         L2 = hist[:, :, i_frame]
    #         #         image_denom = L1 / bluesky[1] + L2 / sun[1]
    #         #         image_x = (L1 * bluesky[0] / bluesky[1] + L2 * sun[0] / sun[1]) / image_denom
    #         #         image_y = (L1 + L2) / image_denom 
    #         #         image_xyz = np.dstack((image_x, image_y, 1 - image_x - image_y))
    #         #         image_rgb = self.cs_srgb.xyz_to_rgb(image_xyz)
    #         #         image_L = (self.opt.min_lum + (1-self.opt.min_lum)* L2) ** (1/self.opt.gamma)
    #         #         image_array = image_L[:, :, None]*image_rgb
    #         #         ax.imshow(image_array, vmin=0, vmax=1)
    #         #     else:
    #         #         ax.imshow(1-image_L, vmin=0, vmax=1)
    #         # fig.savefig(fname, dpi=dpi)
            
    #         fname = f'{self.cachepath}/{self.opt.tag}_frame_{i_frame:04d}.png'
    #         image_array = image_rgb[..., i_frame] ** (1/self.opt.gamma)
    #         np_dtype = np.uint8 if self.opt.n_bits==8 else np.uint16
    #         # imageio.imsave(fname, image_array.astype(np_dtype), dpi=dpi, extension=opt.ext)
    #         img_q = (image_array*(2**self.opt.n_bits-1)).astype(np_dtype)
    #         cv2.imwrite(fname, img_q, [cv2.IMWRITE_PNG_COMPRESSION, 0])
    #         fnames.append(fname)
    #         # plt.close(fig)

    #     if nframe==1:
    #         shutil.move(fname, output_filename)
    #         return output_filename
    #     else:
    #         # if self.opt.ext == 'gif':
    #         #     return make_gif(output_filename, fnames, fps=self.opt.fps)
    #         # else:
    #         return make_mp4(output_filename, fnames, fps=self.opt.fps)
            
    def plot(self, z, image=None, do_color=True, dpi=dpi):
        """
        
        dpi: output resolution - sets the figure size as we ensure there is a one to one correspondance between pixels in the data and the output image
        """

        output_filename = self.get_filename()
        if os.path.isfile(output_filename) and not(self.opt.do_recompute):
            return output_filename
        else:
            # 1/ do the raytracing of image through z:
            binsx, binsy = self.opt.nx//self.opt.bin_dens, self.opt.ny//self.opt.bin_dens
            nx, ny, nframe = z.shape

            # if not specified, use a full image with full contrast (from 0=black to 1=white)
            if image is None: image = np.ones((self.opt.nx, self.opt.ny))


            #image_rgb = self.cs_srgb.spec_to_rgb(hist)
            image_rgb = np.zeros((self.opt.nx//self.opt.bin_dens,  self.opt.ny//self.opt.bin_dens, 3, nframe))
            for i_frame in trange(nframe, desc='Scanning time', position=0, leave=True):
                for i_wavelength in trange(self.opt.bin_spectrum//2, self.N_wavelengths, self.opt.bin_spectrum, desc='Scanning spectrum', position=1, leave=False):
                    modulation = 1. + self.opt.variation/2 - self.opt.variation*i_wavelength/self.N_wavelengths
                    xv, yv = self.transform(z[:, :, i_frame], modulation=modulation)
                    hist_, _, _ = np.histogram2d(xv.ravel(), yv.ravel(),
                                                    bins=[binsx, binsy],
                                                    weights=image.ravel(),
                                                    range=[[0, 1], [0, self.ratio]],
                                                    density=True)

                    # we convert the spectrum into a color
                    spec = np.zeros((self.N_wavelengths))
                    spec[i_wavelength] = 1
                    rgb = self.cs_srgb.spec_to_rgb(spec)
                    rgb *= self.spectrum_sky[i_wavelength]
                    # we add the color to the image
                    image_rgb[:, :, :, i_frame] += hist_[:, :, None] * rgb[None, None, :]

            image_rgb -= image_rgb.min() # HACK
            image_rgb /= image_rgb.max()

            image_rgb = image_rgb ** (1/self.opt.gamma)

            # 2/ transform light into image:
            # output_filename = self.make_frames(image_rgb, output_filename)
            np_dtype = np.uint8 if self.opt.n_bits==8 else np.uint16
            output_filename = make_mp4(output_filename, (image_rgb*(2**self.opt.n_bits-1)).astype(np_dtype), fps=self.opt.fps)
            return output_filename

    def show(self, output_filename, width=1024):
        from IPython.display import HTML, Image, display
        if self.opt.nframe==1:
            # display(Image(url=output_filename.replace(self.opt.ext, 'png'), width=width))
            display(Image(url=output_filename, width=width))
        else:
            if self.opt.ext == 'gif':
                return display(Image(url=output_filename, width=width))
            else:
                #import moviepy.editor as mpy
                #return mpy.ipython_display(output_filename, width=width)
                # https://github.com/NeuralEnsemble/MotionClouds/blob/master/MotionClouds/MotionClouds.py#L858
                opts = ' loop="1" autoplay="1" controls '
                html = HTML(f'<video {opts} src="{output_filename}" type="video/{self.opt.ext}" width={width}\>')
                html.reload()
                return display(html)
# Out:
# <>:194: SyntaxWarning: invalid escape sequence '\>'
# <>:194: SyntaxWarning: invalid escape sequence '\>'
# /var/folders/3p/m0g52j9j69z3gj8ktpgg1dm00000gn/T/ipykernel_26232/425418787.py:194: SyntaxWarning: invalid escape sequence '\>'
#   html = HTML(f'<video {opts} src="{output_filename}" type="video/{self.opt.ext}" width={width}\>')

# %% [markdown]
# # une simple caustique
# ## génération de la caustique

# %%
c = Caustique(opt)

# %%
z = c.wave()
z.shape
# Out:
# (1024, 1024, 96)

# %%
# %whos
# Out:
# Variable         Type                   Data/Info
# -------------------------------------------------
# CM_BY_INCH       float                  2.54
# Caustique        type                   <class '__main__.Caustique'>
# Lambda2color     type                   <class 'lambda2color.Lambda2color'>
# PRECISION        int                    10
# SubplotParams    type                   <class 'matplotlib.gridspec.SubplotParams'>
# c                Caustique              <__main__.Caustique object at 0x12c5cc6e0>
# cv2              module                 <module 'cv2' from '/User<...>ackages/cv2/__init__.py'>
# dataclass        function               <function dataclass at 0x10b03a840>
# dpi              float                  26.0096
# get_ipython      function               <function get_ipython at 0x10ba0c0e0>
# hashlib          module                 <module 'hashlib' from '/<...>b/python3.13/hashlib.py'>
# imageio          module                 <module 'imageio' from '/<...>ges/imageio/__init__.py'>
# init             type                   <class '__main__.init'>
# ip               ZMQInteractiveShell    <ipykernel.zmqshell.ZMQIn<...>ll object at 0x10cf27380>
# make_mp4         function               <function make_mp4 at 0x12b9bb740>
# matplotlib       module                 <module 'matplotlib' from<...>/matplotlib/__init__.py'>
# mc               module                 <module 'MotionClouds' fr<...>ackages/MotionClouds.py'>
# np               module                 <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# opt              init                   init(figpath='2025-10-21_<...>alse, do_recompute=False)
# os               module                 <module 'os' (frozen)>
# planck           function               <function planck at 0x12badfb00>
# plt              module                 <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# pprint           function               <function pprint at 0x10b038c20>
# scattering       function               <function scattering at 0x12bae8e00>
# screen_size_cm   int                    100
# screen_size_in   float                  39.37007874015748
# shutil           module                 <module 'shutil' from '/u<...>ib/python3.13/shutil.py'>
# study_name       str                    2025-10-21_caustique-transition
# subplotpars      SubplotParams          <matplotlib.gridspec.Subp<...>ms object at 0x12b9fbb60>
# tqdm             type                   <class 'tqdm.auto.tqdm'>
# trange           function               <function trange at 0x1296104a0>
# xyz_from_xy      function               <function xyz_from_xy at 0x12b9bb6a0>
# z                ndarray                1024x1024x96: 100663296 elems, type `float64`, 805306368 bytes (768.0 Mb)

# %%
def generate_image(nx, ny, radius_in=.2, radius_out=.4):
    Y, X = np.meshgrid(np.linspace(-1, 1, ny, endpoint=True), np.linspace(-1, 1, nx, endpoint=True))
    image = (X**2 > radius_in**2)  # the horizontal band outside radius_in
    image *= (Y**2 < radius_out**2) # the vertical band inside radius_out
    image *= (X**2 < radius_out**2)  # the horizontal band inside radius_out
    return image*1.

image = generate_image(nx=c.opt.nx, ny=c.opt.ny)

fig, ax = plt.subplots(figsize=(opt.ny/opt.bin_dens/dpi, opt.nx/opt.bin_dens/dpi), subplotpars=subplotpars)

ax.imshow(image, cmap='gray');

# %%
image.min(), image.max(), c.opt.nx, c.opt.ny
# Out:
# (np.float64(0.0), np.float64(1.0), 1024, 1024)

# %%
c = Caustique(opt)
output_filename = c.plot(z, image)
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
c.show(output_filename)
# Out:
# <video  loop="1" autoplay="1" controls  src="2025-10-21_caustique-transition/caustique_4a628b39.mp4" type="video/mp4" width=1024\>

# %% [markdown]
# # exploration des paramètres

# %%
N_scan = 0
base = 2

# %% [markdown]
# ## profondeur d'eau

# %%
for H_ in c.opt.H*np.logspace(-1, 1, N_scan, base=base):
    opt = init()
    c = Caustique(opt)
    c.opt.H = H_
    c.opt.tag = f'{c.opt.tag}_H_{H_:.3f}'
    
    output_filename = c.plot(z, image)
    print(f'H = {H_:.3f} -> {output_filename=} ')
    if c.opt.do_display: c.show(output_filename)

# %% [markdown]
# ## variation de l'indice de réfraction

# %%
# for variation_ in np.logspace(-2, 0, N_scan, base=10, endpoint=False):
#     opt = init()
#     c = Caustique(opt)
#     c.opt.variation = variation_
#     c.opt.tag = f'{opt.tag}_variation_{variation_:.3f}'

#     output_filename = c.plot(z, image)
#     print(f'variation = {variation_:.3f}  -> {output_filename=}')
#     if c.opt.do_display: c.show(output_filename)

# %% [markdown]
# ## post-processing

# %%
# for variable in ['gamma', 'min_lum']: 
for variable in ['gamma']: 
    print(f'======{variable}======')
    for modul in np.logspace(-1, 1, N_scan, base=base):
        opt = init()
        c = Caustique(opt)
        c.d[variable] *= modul
        c.opt.tag = f'{c.opt.tag}_{variable}_modul_{modul:.3f}'
        
        output_filename = c.plot(z, image)
        print(f'{variable}={variable}(default)*{modul:.3f}={c.d[variable]:.3E} -> {output_filename=}')
        if c.opt.do_display: c.show(output_filename)
# Out:
# ======gamma======

# %% [markdown]
# ## paramètres de l'ouverture

# %%
for radius_in in np.linspace(0, 1, N_scan+1)[1:]:
    opt = init()
    c = Caustique(opt)

    c.opt.tag = f'{c.opt.tag}_{type}-image_{radius_in=:.3f}'
    image = generate_image(nx=c.opt.nx, ny=c.opt.ny, radius_in=radius_in)
    output_filename = c.plot(z, image)
    print(f'{radius_in=:.3f} -> {output_filename=} ')
    if c.opt.do_display: c.show(output_filename)

# %%
for radius_out in np.linspace(0, 1, N_scan+1)[1:]:
    opt = init()
    c = Caustique(opt)

    c.opt.tag = f'{c.opt.tag}_{type}-image_{radius_out=:.3f}'
    image = generate_image(nx=c.opt.nx, ny=c.opt.ny, radius_out=radius_out)
    output_filename = c.plot(z, image)
    print(f'{radius_out=:.3f} -> {output_filename=} ')
    if c.opt.do_display: c.show(output_filename)

# %% [markdown]
# ## autres instances de l'onde

# %%
for seed_increment in range(N_scan):
    opt = init()
    c = Caustique(opt)
    c.d['seed'] = c.d['seed'] + seed_increment
    c.opt.tag = f'{c.opt.tag}_seed_{c.d['seed']}'
    # del z
    z = c.wave()
    output_filename = c.plot(z, image)
    print(f'seed={c.d['seed']} -> {output_filename=}')
    if c.opt.do_display: c.show(output_filename)

# %% [markdown]
# ## autres variables sur l'onde

# %%
for variable in ['scale', 'B_sf', 'theta',  'B_theta', 'zmin']: #  'V_Y', 'V_X', 'B_V', 
    print(f'======{variable}======')
    for modul in np.logspace(-1, 1, N_scan, base=base):
        # del z
        opt = init()
        c = Caustique(opt)
        c.d[variable] *= modul
        c.opt.tag = f'{c.opt.tag}_{variable}_modul_{modul:.3f}'
        
        output_filename = c.get_filename()
        if os.path.isfile(output_filename) and not(c.opt.do_recompute):            
            z = c.wave(do_cache=False)
            output_filename_ = c.plot(z, image)
            assert(output_filename == output_filename_)
        print(f'{variable}={variable}(default)*{modul:.3f}={c.d[variable]:.3E} -> {output_filename=}')
        if c.opt.do_display: c.show(output_filename)
# Out:
# ======scale======
# ======B_sf======
# ======theta======
# ======B_theta======
# ======zmin======

# %% [markdown]
# ## une longue vague

# %%
fx, fy, ft = mc.get_grids(opt.nx, opt.ny, opt.nframe)
smooth = (ft - ft.min())/(ft.max() - ft.min()) # smoothly progress from 0. to 1.

# %%
opt.nx, opt.ny, opt.nframe
# Out:
# (1024, 1024, 96)

# %%
opt.nframe
# Out:
# 96

# %%
print('====== long wave ======')
opt = init()
c = Caustique(opt)
        
# N_wave = 4 * PRECISION
N_wave = 5
N_wave = 50
N_wave = 25
amplitude = 1 - np.linspace(-1, 1, N_wave+2)[1:-1]**2 
B_theta = c.opt.B_theta / ( 1 + np.exp(-.5 * (np.linspace(0, 1, N_wave)-.25)**2 / .25**2 ) )
scale = c.opt.scale / ( 1 + np.exp(-.5 * (np.linspace(0, 1, N_wave)-.75)**2 / .25**2 ) )
B_sf = c.opt.B_sf / scale * ( 1 + np.exp(-.5 * (np.linspace(0, 1, N_wave)-.5)**2 / .25**2 ) )

z = None
for i_wave in range(N_wave):
    opt = init()
    c = Caustique(opt)
    # c.opt.do_cache = False
    # c.opt.B_sf = B_sf[i_wave]
    # c.opt.B_theta = B_theta[i_wave]
    # c.opt.scale = scale[i_wave]
    c.opt.seed = opt.seed + i_wave

    print(f'chunk {i_wave+1}/{N_wave}\t {amplitude[i_wave]=:.3f}\t {c.opt.B_sf=:.3f}\t {c.opt.B_theta=:.3f}\t {c.opt.scale=:.3f}\t {c.opt.seed=}')

    z_update = amplitude[i_wave] * c.wave(do_cache=False)

    if z is None:
        z = z_update.copy()
        z_old = z_update.copy()
    else: 
        # print(ft.shape, z_update.shape, z_old.shape)
        # z_new = ft * z_update + (1-ft) * z_old
        # z = np.dstack((z, z_new))
        z = np.concatenate((z, (1.-smooth)*z_old+smooth*z_update), axis=-1)
        z_old = z_update.copy()
    # print(z.shape, z_update.shape)
# Out:
# ====== long wave ======
# chunk 1/25	 amplitude[i_wave]=0.148	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2025
# chunk 2/25	 amplitude[i_wave]=0.284	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2026
# chunk 3/25	 amplitude[i_wave]=0.408	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2027
# chunk 4/25	 amplitude[i_wave]=0.521	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2028
# chunk 5/25	 amplitude[i_wave]=0.621	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2029
# chunk 6/25	 amplitude[i_wave]=0.710	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2030
# chunk 7/25	 amplitude[i_wave]=0.787	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2031
# chunk 8/25	 amplitude[i_wave]=0.852	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2032
# chunk 9/25	 amplitude[i_wave]=0.905	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2033
# chunk 10/25	 amplitude[i_wave]=0.947	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2034
# chunk 11/25	 amplitude[i_wave]=0.976	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2035
# chunk 12/25	 amplitude[i_wave]=0.994	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2036
# chunk 13/25	 amplitude[i_wave]=1.000	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2037
# chunk 14/25	 amplitude[i_wave]=0.994	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2038
# chunk 15/25	 amplitude[i_wave]=0.976	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2039
# chunk 16/25	 amplitude[i_wave]=0.947	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2040
# chunk 17/25	 amplitude[i_wave]=0.905	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2041
# chunk 18/25	 amplitude[i_wave]=0.852	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2042
# chunk 19/25	 amplitude[i_wave]=0.787	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2043
# chunk 20/25	 amplitude[i_wave]=0.710	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2044
# chunk 21/25	 amplitude[i_wave]=0.621	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2045
# chunk 22/25	 amplitude[i_wave]=0.521	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2046
# chunk 23/25	 amplitude[i_wave]=0.408	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2047
# chunk 24/25	 amplitude[i_wave]=0.284	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2048
# chunk 25/25	 amplitude[i_wave]=0.148	 c.opt.B_sf=1.610	 c.opt.B_theta=1.047	 c.opt.scale=632.832	 c.opt.seed=2049

# %%
z.min(), z.mean(), z.max()
# Out:
# (np.float64(0.0006863962201682607),
#  np.float64(0.3461538461538504),
#  np.float64(0.9667399652107858))

# %%
# %whos
# Out:
# Variable          Type                   Data/Info
# --------------------------------------------------
# B_sf              ndarray                25: 25 elems, type `float64`, 200 bytes
# B_theta           ndarray                25: 25 elems, type `float64`, 200 bytes
# CM_BY_INCH        float                  2.54
# Caustique         type                   <class '__main__.Caustique'>
# Lambda2color      type                   <class 'lambda2color.Lambda2color'>
# N_scan            int                    0
# N_wave            int                    25
# PRECISION         int                    10
# SubplotParams     type                   <class 'matplotlib.gridspec.SubplotParams'>
# amplitude         ndarray                25: 25 elems, type `float64`, 200 bytes
# ax                Axes                   Axes(0,0;1x1)
# base              int                    2
# c                 Caustique              <__main__.Caustique object at 0x12ce81f40>
# cv2               module                 <module 'cv2' from '/User<...>ackages/cv2/__init__.py'>
# dataclass         function               <function dataclass at 0x10b03a840>
# dpi               float                  26.0096
# fig               Figure                 Figure(3937.01x3937.01)
# ft                ndarray                1024x1024x96: 100663296 elems, type `float64`, 805306368 bytes (768.0 Mb)
# fx                ndarray                1024x1024x96: 100663296 elems, type `float64`, 805306368 bytes (768.0 Mb)
# fy                ndarray                1024x1024x96: 100663296 elems, type `float64`, 805306368 bytes (768.0 Mb)
# generate_image    function               <function generate_image at 0x12ca223e0>
# get_ipython       function               <function get_ipython at 0x10ba0c0e0>
# hashlib           module                 <module 'hashlib' from '/<...>b/python3.13/hashlib.py'>
# i_wave            int                    24
# image             ndarray                1024x1024: 1048576 elems, type `float64`, 8388608 bytes (8.0 Mb)
# imageio           module                 <module 'imageio' from '/<...>ges/imageio/__init__.py'>
# init              type                   <class '__main__.init'>
# ip                ZMQInteractiveShell    <ipykernel.zmqshell.ZMQIn<...>ll object at 0x10cf27380>
# make_mp4          function               <function make_mp4 at 0x12b9bb740>
# matplotlib        module                 <module 'matplotlib' from<...>/matplotlib/__init__.py'>
# mc                module                 <module 'MotionClouds' fr<...>ackages/MotionClouds.py'>
# np                module                 <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# opt               init                   init(figpath='2025-10-21_<...>alse, do_recompute=False)
# os                module                 <module 'os' (frozen)>
# output_filename   str                    2025-10-21_caustique-tran<...>on/caustique_4a628b39.mp4
# planck            function               <function planck at 0x12badfb00>
# plt               module                 <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# pprint            function               <function pprint at 0x10b038c20>
# scale             ndarray                25: 25 elems, type `float64`, 200 bytes
# scattering        function               <function scattering at 0x12bae8e00>
# screen_size_cm    int                    100
# screen_size_in    float                  39.37007874015748
# shutil            module                 <module 'shutil' from '/u<...>ib/python3.13/shutil.py'>
# smooth            ndarray                1024x1024x96: 100663296 elems, type `float64`, 805306368 bytes (768.0 Mb)
# study_name        str                    2025-10-21_caustique-transition
# subplotpars       SubplotParams          <matplotlib.gridspec.Subp<...>ms object at 0x12b9fbb60>
# tqdm              type                   <class 'tqdm.auto.tqdm'>
# trange            function               <function trange at 0x1296104a0>
# variable          str                    zmin
# xyz_from_xy       function               <function xyz_from_xy at 0x12b9bb6a0>
# z                 ndarray                1024x1024x2400: 2516582400 elems, type `float64`, 20132659200 bytes (19200.0 Mb)
# z_old             ndarray                1024x1024x96: 100663296 elems, type `float64`, 805306368 bytes (768.0 Mb)
# z_update          ndarray                1024x1024x96: 100663296 elems, type `float64`, 805306368 bytes (768.0 Mb)

# %%
del z_old 
del z_update

# %%
z.shape
# Out:
# (1024, 1024, 2400)

# %%
z /= z.max()

# %%
c.opt.tag = 'full_vave'
c.opt.gamma = 1

output_filename = c.get_filename()
# mc.anim_save(z, output_filename)
# output_filename = c.make_frames(z, output_filename)

np_dtype = np.uint8 if self.opt.n_bits==8 else np.uint16
output_filename = make_mp4(output_filename, (z*(2**c.opt.n_bits-1)).astype(np_dtype), fps=c.opt.fps)
c.show(output_filename)
# Out:
# Lossy conversion from float64 to uint8. Range [1.0835029157952087, 37.98214193780159]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.1010949862959265, 38.00162703789911]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0781999732878558, 38.01849695442346]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.049958643999306, 38.02302954784929]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.042719789635826, 38.022149789730676]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0592104046814457, 38.00640530146987]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0999173505030442, 37.97629788704171]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.1660842689588182, 37.93481756302793]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.261152239323813, 37.87887862139942]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.3820141056131094, 37.81289238984602]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.5252446854441846, 37.732774034417]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.6810478405703757, 37.64049582659003]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.817038115340548, 37.59801533626836]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.95793409975014, 37.59698932435327]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1040658592549635, 37.59569053798388]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.2593931382571792, 37.58937383378332]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.421496631096123, 37.5808032094183]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.5896729266928453, 37.57356756877066]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.7632160673592847, 37.59019087376362]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.9373895381188495, 37.62089204455708]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.1101720410741973, 37.65135719872905]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.278868111532163, 37.67969672150098]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.442639957243196, 37.70489492640181]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.55817587565109, 37.72675332912577]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.4391528121124852, 37.74870032050545]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.3214228667536347, 37.77236442612125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.2068772388791817, 37.800767913924744]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.095963892719236, 37.834578324950996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.985172036132535, 37.87094946264433]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.873793315883607, 37.90364972411445]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.764228907775567, 37.93191618431632]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.655520639316328, 37.95662742486122]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.5545444373110215, 37.979236025867]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.4587809366961113, 38.00076580991909]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.3716218443157655, 38.019999713101164]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.2971667403540605, 38.036433461048546]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.234432241645126, 38.045521281004184]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1857697528715243, 38.04425911494592]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.149317979813086, 38.03623076255054]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.128341870243233, 38.02418063158029]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1133351926624173, 38.023868119647766]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1114631323333746, 38.037113761199954]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1164278997437243, 38.0529377903467]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.129580365590652, 38.0649896452376]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1472365492708434, 38.08120454939287]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1690132876242707, 38.105357538684004]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.188978183810521, 38.14150131602104]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.2066446820551198, 38.192660095572535]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.220730730950557, 38.25087316158395]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.227219364909256, 38.31554046603325]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.2290528285456075, 38.38188431096517]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.224010286029534, 38.45185022853241]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.208919715693594, 38.52056875753066]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1897784057144327, 38.58753321288932]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1758626171564797, 38.65173456837007]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1477363295211096, 38.711235389344424]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1235189251771778, 38.763290400891414]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0950380164677562, 38.810072420025584]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.075992981657962, 38.85049203064621]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0583685023122626, 38.88313631974918]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.048557227134203, 38.91368024807068]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.042020473342549, 38.94455067237222]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0460907495489318, 38.97662751183208]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.057099506400548, 39.00328333169578]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0781614797681733, 39.01850268322741]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1088178092356595, 39.01968972897426]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.146184559018999, 39.00616160650433]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1872151772726616, 38.9812639194096]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.2252729218407987, 38.948985517969504]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.2407718868361313, 38.91367734622556]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.2069218620574564, 38.874343022265776]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1513526310018154, 38.8324182671397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.104541111564741, 38.78988734013662]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0672619561573913, 38.74753416858624]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0420295243747786, 38.70073962021046]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.018402804304194, 38.65015395601696]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.976498823944621, 38.59710008377651]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.8927049076440678, 38.54343212301311]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.7718164392833595, 38.49100012634017]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.6511658160608684, 38.4410189089946]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.537933022086644, 38.39308922993259]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.4354369634050341, 38.34511390755698]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.3429883437662409, 38.300968789209904]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.2655764872454516, 38.26496021042149]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.2017188521658984, 38.23547597400327]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.1484050719390706, 38.20864221780666]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.107495280070487, 38.18330303182156]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.078701574459747, 38.15767186513037]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.061535970780108, 38.12878137260675]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0552157199139767, 38.11101677614035]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0561731257150304, 38.09705057278027]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0612844270871455, 38.074064362646816]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0657999216120884, 38.03902883644978]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0669910894781423, 37.99222692638439]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0666603713182594, 37.945868340425925]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0719534830441624, 37.95539153068591]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0835029157952087, 37.98214193780159]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.6046212278177492, 37.836255252885685]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0914822014082444, 37.68312086911537]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.567356355732592, 37.519984573256984]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.061844044142986, 37.34370652415718]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.5771587494683295, 37.46566504665395]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.115598584199049, 37.62694084627727]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.675352492219583, 37.7766398571735]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.2593845150539815, 37.91423408650802]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.864360516112212, 38.039320829368776]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.485337748007192, 38.15041417082928]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.102448002685584, 38.24964511478543]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.711025303812968, 38.335826318414405]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.320079151778504, 38.41286763051437]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.81528290594389, 38.4856310480215]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.018903724665638, 38.558432105247505]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.218818513021194, 38.636308582962265]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.415278616616506, 38.7251527687623]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.608354416978584, 38.82282770811804]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.796658973935143, 38.95358097360781]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.983481329391473, 39.08995615652797]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.172060086308845, 39.2239947539336]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.357226707068964, 39.35544009989467]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.543449694969155, 39.486464528919704]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.729258765414817, 39.62047119279029]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.91150933056745, 39.76719518329949]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.092272171040836, 39.91581478933177]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.270391783437958, 40.06464086682422]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.443991478503602, 40.21608084100741]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.616838627810822, 40.37381795169053]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.78937009299874, 40.53812005505241]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.961896254570604, 40.710294864498636]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.132535198567567, 40.88501895039675]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.304584967150745, 41.057766014339904]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.475353726945052, 41.224876562303294]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.648295910168626, 41.38226781142165]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.81972125327001, 41.52921987561194]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.90269127273348, 41.66511117854584]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.820455502860783, 41.79264313316271]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.742944480969083, 41.913014958387194]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.668747408031349, 42.02616993093601]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.600446113626363, 42.13348063772899]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.53825015682472, 42.47459685755293]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.481574562154682, 42.84631838901532]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.431811538625151, 43.21455641618673]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.387139198186292, 43.583905331612016]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.345246064519134, 43.95196995010697]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.305353730386088, 44.32012575217159]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.263958409756418, 44.68893875800142]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.19883187701292, 45.271600344577095]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.113871188078438, 45.89294717318754]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.01481399303748, 46.505443076641576]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.90012667900343, 47.11179489164644]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.77061838701314, 47.712665422853675]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.626213306833716, 48.31035805524258]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.46692075579066, 48.90489959172775]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.288177623116162, 49.496887302901776]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.080302905032312, 50.086346233151296]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.846923744809203, 50.67328009413288]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.599884675316744, 51.26083834202303]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.349325126974216, 51.8537692329836]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.100805740375428, 52.451208045431905]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.85335051692831, 53.056532572937094]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.61090423002967, 53.66503822781977]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.376201017399987, 54.278450540832125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.14933539928537, 54.89193327369643]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.935122080786952, 55.5103968364969]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.732327622625098, 56.130228274899984]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.544181412493064, 56.75384941695756]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.373811139025076, 57.386179258211044]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.216414589109938, 58.02682737132861]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.076893626771776, 58.671026388169274]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.953311093282403, 59.3176939116314]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.848655966768771, 59.960441069612095]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.762029878417127, 60.602931500919624]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.692340805255141, 61.243996603657486]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.637802019515097, 61.88275320109872]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.596566217875624, 62.52052782755588]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.5665229750986045, 63.15962368751409]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.543531818173545, 63.80018389570122]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.525313839642689, 64.44228540797036]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.505730867870855, 65.08809281973288]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.483554328307522, 65.7365772537155]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.45757709710031, 66.38823250618906]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.42504994368453, 67.04429252651748]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.387034795097694, 67.70322903709851]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.344180113828754, 68.36583416376345]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.297380424096121, 69.03760624385221]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.246202218013989, 69.71467180755384]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.191536857027616, 70.40213276731197]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.1327823219723, 71.11587209372661]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.06957025045864, 71.86188645948552]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.998837485412155, 72.6178826094676]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.921432197077831, 73.3675453066668]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.836368102652088, 74.10241871834187]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.743846875450597, 74.81671615628309]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.7655888208997, 74.87422636816764]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.992223856173682, 74.7212415265009]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.212327841209503, 74.55002905725563]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.429805230061714, 74.35507339650277]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.643472455174095, 74.14585904908591]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.857277676841796, 73.92173897093542]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.070832773808219, 73.68407223561321]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.28534365148828, 73.43452865218542]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.501209491045152, 73.17295091606938]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.719770145702036, 72.90391457480706]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.944997836072805, 72.62813370563012]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.176808082757525, 72.34803812110067]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.413219816225437, 72.06691933329071]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.657410874412314, 71.78889006951056]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.908415155296348, 71.51801080727145]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.164878031745298, 71.25367669859767]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.425093447684779, 70.99901493951462]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.687856929561226, 70.78919010397566]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.952202516400037, 70.60566008138075]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.22012975162778, 70.42351357312579]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.49172996651985, 70.24195455795814]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.766249494736368, 70.06240075210866]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.04684665713537, 69.88811711177252]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.333909436446456, 69.71863892570411]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.62224443752271, 69.55826777213919]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.913278537483329, 69.40775798450717]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.202858642784003, 69.26497193419569]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.275614352763547, 69.1319461605465]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.361446877351597, 69.00645342791042]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.464377271509504, 68.88964185705122]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.582154908067793, 68.78696822233238]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.717393170115116, 68.69900455170549]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.869441266761212, 68.63077065178962]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [14.033597723758108, 68.58926878926735]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [14.213524889927465, 68.57475925985842]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [14.186793836983464, 68.578380269173]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [14.11952064599809, 68.60036265381066]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [14.070111009225423, 68.63587401533694]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [14.035569282951483, 68.6883235482178]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [14.006982966663115, 68.75520765151221]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.970655634750194, 68.83602297838318]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.916965435182636, 68.92981972430866]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.844185431556479, 69.03228322758251]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.74731055119535, 69.14089996622572]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.627202556149605, 69.46769208139942]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.484344218732133, 69.99255807305254]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.319723771419296, 70.51713593177183]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.139383393071187, 71.04432744226766]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.949566165591927, 71.5730440787099]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.755691309684487, 72.10588789704978]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.562357964557162, 72.63918784430894]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.370468263585401, 73.16855074707459]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.183843478484855, 73.69188695974715]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.000544167032208, 74.20637803548914]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.816457828169154, 74.7083439869446]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.631273949577354, 75.19861765827628]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.444682483130887, 75.67433635617701]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.250602442916193, 76.13833194605874]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.037012286248821, 76.59527993426566]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.771181600458103, 77.04409706288737]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.388782889139488, 77.48884394729114]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.955349328373496, 77.9293301592121]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.526863397914465, 78.36072337518713]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.102899545770114, 78.77933179105878]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.69136651857292, 79.1800383059716]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.293000775044542, 79.56565854283298]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.91074267155084, 79.93731886231008]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.5452619069017235, 80.29957565888441]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.204496877849891, 80.65668392494202]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.891983844534199, 81.00735887669828]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.605100447456124, 81.35221631070833]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.347148932270298, 81.6925092553639]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.119418816294157, 82.0336927226635]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.914546362988151, 82.38602261332339]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.735969189647194, 82.75069045965164]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.57774324043795, 83.41670819278359]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.442361236101474, 84.12522086027488]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.326251140754738, 84.81527678196001]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.239173320363384, 85.48332511905434]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.1714916819787105, 86.13343166714947]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.129554361121851, 86.76371935325584]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.109680789390082, 87.58587638224505]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.107983131394273, 88.4136571348546]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.119901744321891, 89.22318087586285]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.143962969182613, 90.01978133309511]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.176210170569285, 90.78805281477595]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.201717025503915, 91.53449381145661]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.217830648558758, 92.249676253856]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.229253905906955, 92.95286184024421]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.2484705470100925, 93.64846177425461]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.271532943026516, 94.34489607433865]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.285910665067147, 95.05684024482986]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.2762490392027965, 95.79388219514131]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.234398069406569, 96.56376645659375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.178783490909796, 97.35980697366936]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.117684408059718, 98.1613330462296]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.288242347023182, 98.3234720134963]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.825018454591245, 98.206556471813]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.3677256389506525, 98.04760152722113]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.915745819469512, 97.84334928557654]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.465375116616761, 97.58365446257764]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.010126086328317, 97.26704063945289]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.553069026119067, 96.91281050896876]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.087038160007255, 96.5070973145104]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [9.605485558680522, 96.06350017905156]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.113154337526147, 95.5750226619186]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.594688373867669, 95.05011100810204]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.067159660073804, 94.49667741119741]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.544517513865642, 93.9150366646516]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.029056070375253, 93.31719206616667]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.283226456660575, 93.28167274005052]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.536957194385527, 93.29038193203759]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [12.802592145301528, 93.30655752605693]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.060129691301446, 93.32955574108935]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.249899569702464, 93.35816775845832]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.356580327056081, 93.38718989733694]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.442210672263206, 93.40586177926386]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.511317615921797, 93.4123396311542]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.56577410800798, 93.40413291099989]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.607480017124738, 93.38044048419079]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.632551654657973, 93.34390632614675]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.638978864540627, 93.29755398441075]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.629202556167046, 93.234257959362]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.598967530502916, 93.16190544135131]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# Lossy conversion from float64 to uint8. Range [7.292376353358176, 72.92046869891705]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.712259441398182, 73.15900286822759]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.095953050729312, 73.38197912791017]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.461002660657186, 73.59850554739067]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.815403564104523, 73.81819854936414]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.16298087186678, 74.04299619346396]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.50931924254763, 74.27877473925403]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.8586648065619933, 74.51577211567712]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.8123964416148706, 74.59170998370854]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.894639502746408, 74.01976918338123]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.98687004190425, 73.43641617213676]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.092051468786851, 72.83787011743296]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.2100753455525024, 72.2237016278935]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.341784198932854, 71.58761158058452]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.484182989630143, 70.93502077390524]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.6370859855321855, 70.2622004665077]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.801565439795465, 69.57081779665486]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.9718419889746004, 68.86625660733557]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.147850306636416, 68.14500661119136]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.321270786322926, 67.40742871039875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.490732133020685, 66.65868042575649]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.656031874847921, 65.89918994973706]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.818707566944549, 65.13073186205875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.972375207899376, 64.35618758359311]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.121794950229908, 63.5811505593671]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.26599496763571, 62.80624604952606]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.407071652854678, 62.03015178748293]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.547402211920087, 61.25306674297426]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.68226717200299, 60.47989216258549]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.8124297173277295, 59.71291691380359]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.934987995361289, 58.94895431483336]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.051348804515901, 58.19324511122616]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.082088969833315, 57.522124004643224]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [6.03246492466994, 56.866402950964776]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.977042989173044, 56.20586368293356]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.914846406144135, 55.54278405969276]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.848845356714176, 54.883239491205465]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.783430509003165, 54.22464046169118]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.722270363179864, 53.56658880216804]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.665047286022272, 52.908475340414554]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.612664530267174, 52.24846930783735]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.563898160462569, 51.58644623838527]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.519776588150785, 50.92534161787338]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.475332001703735, 50.45577377043686]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.423906464847961, 50.038726753128074]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.365503201704824, 49.62789006819066]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.305267473395901, 49.24080223250946]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.252015449656068, 48.85762323341072]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.211714845736495, 48.474631578757496]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.185099658816089, 48.09351649332209]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.170144207468374, 47.727517089954375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.165861440887173, 47.36585597819202]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.171512673536162, 46.99971427212667]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.185228692351589, 46.62769132815911]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.210167754247738, 46.24543731293282]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.244610874968736, 45.85624010505517]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.277128973223873, 45.45972713333021]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.2947867488474305, 45.058246794652575]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.303395331903045, 44.66799892568201]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.304553101000348, 44.298512802813136]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.29120099757802, 43.9346489273667]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.217867218001305, 43.574631486583954]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.139747319092917, 43.22198326443691]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [5.062865345039369, 42.87309569687183]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.989578879471614, 42.528947908471864]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.92170859872863, 42.194447211098044]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.858690332048424, 41.872810428263435]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.793862833823688, 41.55495488446133]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.728228604047977, 41.23596795241453]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.659601046699688, 40.91356009121059]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.593474464151889, 40.58743467595285]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.536934210925547, 40.25809914665033]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.490640345586105, 39.92603655895728]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.4616334697761, 39.59399414857659]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.447664691439643, 39.26175984106954]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.449357963577934, 38.93167373135585]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.465847023378704, 38.62978243373776]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.496959106370211, 38.359518362489865]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.539665166925988, 38.09752676825643]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.59404759009119, 37.83644122236929]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.657384043474907, 37.571997859134555]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.717412436922488, 37.304245872877786]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.612816846279474, 37.030544981105876]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.511657680113746, 36.75038870179732]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.412029214559934, 36.463325418491294]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.314480411707884, 36.166601788825865]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.214373968687938, 35.86158215150063]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.110461579444749, 35.55978361433159]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [4.00087135141102, 35.36197026267906]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.8841886510827583, 35.17726859938111]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.7578189090571534, 35.020521899684994]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.623734630942029, 34.86742357044634]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.483697548293279, 34.71630608987225]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.339391228165284, 34.80134882633583]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.1952697636034606, 34.88888911069617]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [3.0514712039780134, 34.97611979935794]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.9114372771806662, 35.061277740762534]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.777058986493749, 35.14332593002167]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.6494372724888477, 35.22117200777292]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.531324097446064, 35.29733983947155]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.423908155755917, 35.369657154989945]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.331339504672364, 35.441494583626074]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.247604805477275, 35.517135540718506]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.1770612310326025, 35.599742257945266]. Convert image to uint8 prior to saving to suppress this warning.
# <video  loop="1" autoplay="1" controls  src="2025-10-21_caustique-transition/full_vave_5391ca5d.mp4" type="video/mp4" width=1024\>

# %%
z.ndim
# Out:
# 3

# %%
c = Caustique(opt)
c.opt.tag = 'full_caustics'
output_filename = c.plot(z, image)
# Out:
#   0%|          | 0/2400 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# ...
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
c.show(output_filename)
# Out:
# <video  loop="1" autoplay="1" controls  src="2025-10-21_caustique-transition/full_caustics_cfebfc9b.mp4" type="video/mp4" width=1024\>
